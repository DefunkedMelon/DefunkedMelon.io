# %% [markdown]
# # Data Science for Dummies
# *A comprehensive guide to the data science pipeline by Elan Naideck and Erika Shlunk*

# %% [markdown]
# ## Before you begin

# %% [markdown]
# ## Data Collection

# %% [markdown]
# #### Let's grab the class data from Piazza

# %%
from piazza_api.rpc import PiazzaRPC

# Below is the class id. Needed for querying any data for the classes. Don't ask how I got it
# class nid: jzlv5mrrqnn4tz

# Create a piazza instance and login to it
# DON'T FORGET TO REMOVE THE PASSWORD BEFORE POSTING IT ONLINE
p = PiazzaRPC()
p.user_login(email='enaideck@umd.edu', password='chaseand1')

# The returned data structure is a dictionary containing tons of data about the class
# It has to be sifted through to get a post list
class_data = p.get_my_feed(limit=2000, offset=0, sort="recent", nid='jzlv5mrrqnn4tz')
posts_dict = class_data['feed']
posts_dict
# Out:
# [{'fol': 'project4|',
#   'pin': 1,
#   'm': 1575313343571,
#   'rq': 0,
#   'id': 'k3osw3839eu1f6',
#   'unique_views': 48,
#   'score': 48.0,
#   'is_new': False,
#   'version': 1,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['project4'],
#   'nr': 551,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T19:02:23Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'}],
#   'subject': 'Project 4 Key',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'pin', 'project4'],
#   'gd_f': 0,
#   'content_snipet': 'In a previous class, a student had experience operating on the type of data used in P4; she wrote the following, which I',
#   'view_adjust': 0,
#   'modified': '2019-12-02T19:02:23Z',
#   'gd': 1,
#   'updated': '2019-12-02T19:02:23Z',
#   'status': 'active'},
#  {'fol': 'midterm_exam|',
#   'pin': 1,
#   'm': 1574268981850,
#   'rq': 0,
#   'id': 'k35zogl87lw5nx',
#   'unique_views': 259,
#   'score': 259.0,
#   'is_new': True,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['midterm_exam'],
#   'nr': 429,
#   'main_version': 11,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-19T15:04:47Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-19T15:06:11Z', 'n': 'followup'},
#    {'t': '2019-11-19T15:07:52Z', 'u': 'ikq4ua6j9dp38z', 'n': 'followup'},
#    {'t': '2019-11-19T15:09:04Z', 'n': 'feedback'},
#    {'t': '2019-11-19T15:10:12Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-19T15:10:24Z', 'u': 'jl3b2jmi38z3wh', 'n': 'followup'},
#    {'t': '2019-11-19T15:20:37Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-19T15:23:35Z', 'u': 'jm6ikg6z5m81e2', 'n': 'followup'},
#    {'t': '2019-11-19T17:12:04Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-19T18:05:54Z', 'u': 'j6rz1px06pl629', 'n': 'feedback'},
#    {'t': '2019-11-20T16:56:21Z', 'n': 'feedback'}],
#   'subject': 'Midterm grades posted',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'midterm_exam', 'pin'],
#   'content_snipet': 'We&#39;ve posted midterm grades on GradeScope.\xa0 A few midterms are missing from those who took the exam via ADS; I&#39;l',
#   'view_adjust': 0,
#   'modified': '2019-11-20T16:56:21Z',
#   'updated': '2019-11-19T15:04:47Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'pin': 1,
#   'm': 1574114977824,
#   'rq': 0,
#   'id': 'k34o5uf2wb63ee',
#   'unique_views': 273,
#   'score': 273.0,
#   'is_new': True,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['project3'],
#   'nr': 423,
#   'main_version': 8,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-18T16:54:37Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-18T16:54:59Z', 'u': 'jl3b2jmi38z3wh', 'n': 'followup'},
#    {'t': '2019-11-18T16:55:33Z', 'n': 'followup'},
#    {'t': '2019-11-18T16:56:31Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'update'},
#    {'t': '2019-11-18T16:59:32Z', 'n': 'followup'},
#    {'t': '2019-11-18T17:00:49Z', 'n': 'followup'},
#    {'t': '2019-11-18T18:46:07Z', 'n': 'followup'},
#    {'t': '2019-11-18T22:09:37Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'}],
#   'subject': 'Extension on Project 3',
#   'no_answer_followup': 0,
#   'num_favorites': 1,
#   'type': 'note',
#   'tags': ['instructor-note', 'pin', 'project3'],
#   'content_snipet': 'I&#39;m extending P3&#39;s due date to next Monday, 11/25.\xa0 This project is a bit chaotic.\n\n(Please\xa0make sure you have s',
#   'view_adjust': 0,
#   'modified': '2019-11-18T22:09:37Z',
#   'gd': 12,
#   'updated': '2019-11-18T16:54:37Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'pin': 1,
#   'm': 1573665516224,
#   'rq': 0,
#   'id': 'k2wi7zmj8t15vc',
#   'unique_views': 281,
#   'score': 281.0,
#   'is_new': False,
#   'version': 3,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['project3'],
#   'nr': 370,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-12T23:46:10Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-13T17:17:41Z', 'n': 'followup'},
#    {'t': '2019-11-13T17:18:36Z', 'n': 'feedback'}],
#   'subject': 'Update to Project 3',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'pin', 'project3'],
#   'content_snipet': 'I&#39;ve updated Project 3 by\xa0removing\xa0Question 7/Exercise 13.\xa0 We&#39;re still running behind, and we won&#39;t get to ',
#   'view_adjust': 0,
#   'modified': '2019-11-13T17:18:36Z',
#   'gd': 1,
#   'updated': '2019-11-12T23:46:10Z',
#   'status': 'active'},
#  {'fol': 'midterm_exam|',
#   'pin': 1,
#   'm': 1574137021210,
#   'rq': 0,
#   'id': 'k25efaof64v6lw',
#   'unique_views': 277,
#   'score': 277.0,
#   'is_new': False,
#   'version': 4,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['midterm_exam'],
#   'nr': 317,
#   'main_version': 7,
#   'request_instructor': 0,
#   'log': [{'t': '2019-10-25T00:30:05Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-12T18:30:36Z', 'n': 'followup'},
#    {'t': '2019-11-12T19:18:56Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-12T20:11:20Z', 'n': 'feedback'},
#    {'t': '2019-11-18T19:09:04Z', 'n': 'feedback'},
#    {'t': '2019-11-18T22:08:15Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-19T04:17:01Z', 'u': 'jzucg56coc25pl', 'n': 'feedback'}],
#   'subject': 'Midterm Follow-Up',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'midterm_exam', 'pin'],
#   'content_snipet': 'Thanks to everyone who sat for today&#39;s midterm!\xa0 I think it went well.\xa0 Just a quick note: we have a few students wh',
#   'view_adjust': 0,
#   'modified': '2019-11-19T04:17:01Z',
#   'updated': '2019-10-25T00:30:05Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575310380835,
#   'rq': 0,
#   'id': 'k3or4l5v3874iq',
#   'unique_views': 31,
#   'score': 31.0,
#   'is_new': True,
#   'bucket_name': 'Today',
#   'bucket_order': 2,
#   'folders': ['project4'],
#   'nr': 550,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T18:13:00Z', 'n': 'create'}],
#   'subject': 'Map not showing on notebook but works on HTML',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project4', 'student', 'unanswered'],
#   'gd_f': 0,
#   'content_snipet': 'I&#39;m about to submit my project but noticed that the map does not show in the notebook but it does show up correctly ',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-12-02T18:13:00Z',
#   'gd': 5,
#   'updated': '2019-12-02T18:13:00Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575262917735,
#   'rq': 0,
#   'id': 'k3nyjeao7fz197',
#   'unique_views': 50,
#   'score': 50.0,
#   'is_new': True,
#   'd-bucket': 'Yesterday',
#   'bucket_name': 'Yesterday',
#   'bucket_order': 3,
#   'folders': ['project4'],
#   'nr': 548,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T04:52:42Z', 'n': 'create'},
#    {'t': '2019-12-02T05:01:57Z', 'u': 'jlci7zk6mz66x7', 'n': 's_answer'}],
#   'subject': 'Notebook crashes when adding many markers',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I&#39;m adding a large number of markers (one for every crime) to the map.\nWhen I attempt to display the map after addin',
#   'modified': '2019-12-02T05:01:57Z',
#   'gd': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-12-02T04:52:42Z',
#   'status': 'active'},
#  {'fol': 'quiz12|',
#   'm': 1575312246299,
#   'rq': 0,
#   'id': 'k3nwrh54w3o58i',
#   'unique_views': 60,
#   'score': 60.0,
#   'is_new': True,
#   'd-bucket': 'Yesterday',
#   'bucket_name': 'Yesterday',
#   'bucket_order': 3,
#   'folders': ['quiz12'],
#   'nr': 547,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T04:03:00Z', 'n': 'create'},
#    {'t': '2019-12-02T18:44:06Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'Reading Quiz 12',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Is there going to be a 12th quiz? If not, are two quizzes still going to be dropped, and are the quizzes still going to ',
#   'modified': '2019-12-02T18:44:06Z',
#   'gd': 1,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['quiz12', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-12-02T04:03:00Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575296781240,
#   'rq': 0,
#   'id': 'k3no8qfn42z6n4',
#   'unique_views': 66,
#   'score': 66.0,
#   'is_new': True,
#   'd-bucket': 'Yesterday',
#   'bucket_name': 'Yesterday',
#   'bucket_order': 3,
#   'folders': ['project4'],
#   'nr': 546,
#   'main_version': 6,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T00:04:29Z', 'n': 'create'},
#    {'t': '2019-12-02T00:04:59Z', 'n': 'update'},
#    {'t': '2019-12-02T00:07:47Z', 'n': 'update'},
#    {'t': '2019-12-02T00:08:32Z', 'n': 'update'},
#    {'t': '2019-12-02T00:08:44Z', 'n': 'update'},
#    {'t': '2019-12-02T14:26:21Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Ignore',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Nvmd, resolved',
#   'modified': '2019-12-02T14:26:21Z',
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-12-02T00:04:29Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575258615366,
#   'rq': 0,
#   'id': 'k3nl9gtk6z27c0',
#   'unique_views': 79,
#   'score': 79.0,
#   'is_new': True,
#   'd-bucket': 'Yesterday',
#   'bucket_name': 'Yesterday',
#   'bucket_order': 3,
#   'folders': ['project4'],
#   'nr': 544,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-01T22:41:04Z', 'n': 'create'},
#    {'t': '2019-12-01T22:50:56Z', 'n': 's_answer'},
#    {'t': '2019-12-01T22:52:57Z', 'n': 'followup'},
#    {'t': '2019-12-02T03:50:15Z', 'n': 'feedback'}],
#   'subject': 'Does anyone know what &#39;I&#39; is in the race column?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': 'Also, &#34;A&#34; means asian right?\xa0',
#   'modified': '2019-12-02T03:50:15Z',
#   'gd': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-12-01T22:41:04Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575160686930,
#   'rq': 0,
#   'id': 'k3ma04lukrx1d7',
#   'unique_views': 75,
#   'score': 75.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 543,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-01T00:38:06Z', 'n': 'create'}],
#   'subject': 'HeatMapWithTime (probably) not working',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Just a heads up, the HeatMapWithTime folio plugin seems to be broken, so if you&#39;re thinking of using it, it might be',
#   'modified': '2019-12-01T00:38:06Z',
#   'gd': 3,
#   'num_favorites': 0,
#   'tags': ['project4', 'student', 'unanswered'],
#   'tag_good_prof': 1,
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 1,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-12-01T00:38:06Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575227950282,
#   'rq': 0,
#   'id': 'k3m6v2bncvg5n1',
#   'unique_views': 97,
#   'score': 97.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 542,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-30T23:10:11Z', 'n': 'create'},
#    {'t': '2019-11-30T23:12:14Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'},
#    {'t': '2019-12-01T19:19:10Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'What exactly is the &#34;write-up&#34; for project 4? Is it the same thing as the short prose description?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 4,
#   'content_snipet': '',
#   'modified': '2019-12-01T19:19:10Z',
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-30T23:10:11Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575228138830,
#   'rq': 0,
#   'id': 'k3m4smk5bo9761',
#   'unique_views': 83,
#   'score': 83.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 541,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-30T22:12:18Z', 'n': 'create'},
#    {'t': '2019-11-30T22:14:17Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'},
#    {'t': '2019-11-30T22:14:32Z', 'u': 'j6wriis2x1oic', 'n': 's_answer_update'},
#    {'t': '2019-12-01T19:22:18Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'Map won&#39;t show up in jupyter notebook',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I&#39;m trying to mark the location of crime in Jupyter Notebook with circles. However, Jupyter notebook cannot render t',
#   'modified': '2019-12-01T19:22:18Z',
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-30T22:12:18Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575301867616,
#   'rq': 0,
#   'id': 'k3l9rtkkmc46jh',
#   'unique_views': 87,
#   'score': 87.0,
#   'is_new': False,
#   'version': 2,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 540,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-30T07:43:53Z', 'n': 'create'},
#    {'t': '2019-11-30T08:52:41Z', 'n': 's_answer'},
#    {'t': '2019-12-01T21:16:57Z', 'n': 'followup'},
#    {'t': '2019-12-02T15:51:07Z', 'u': 'idx3g94pfq357h', 'n': 'feedback'}],
#   'subject': 'What does &#34;U” represent in race?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': 'In project 4 given dataset race column. U represent which race?',
#   'modified': '2019-12-02T15:51:07Z',
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-30T07:43:53Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575065112750,
#   'rq': 0,
#   'id': 'k3koa7oszki4zu',
#   'unique_views': 103,
#   'score': 103.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 537,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-29T21:42:19Z', 'n': 'create'},
#    {'t': '2019-11-29T22:05:12Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'}],
#   'subject': 'Project 4 Submission Clarification',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': '\n\n\n\nFor project 4, do I only submit the notebook file as usual? Do I need to submit the HTML file of the\xa0embedded map as',
#   'modified': '2019-11-29T22:05:12Z',
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-29T21:42:19Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575057868884,
#   'rq': 0,
#   'id': 'k3kg167wevf151',
#   'unique_views': 100,
#   'score': 100.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 533,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-29T17:51:21Z', 'n': 'create'},
#    {'t': '2019-11-29T20:04:28Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'GroupBy Certain Criteria',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 3,
#   'content_snipet': 'For Project #4, suppose I wanted to create multiple maps displaying crime by sex/race and group by a certain criteria (i',
#   'modified': '2019-11-29T20:04:28Z',
#   'gd': 2,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'tag_good_prof': 1,
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-29T17:51:21Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575057650237,
#   'rq': 0,
#   'id': 'k3ji3jp95ym3b2',
#   'unique_views': 97,
#   'score': 97.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 532,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-29T02:01:24Z', 'n': 'create'},
#    {'t': '2019-11-29T20:00:29Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'},
#    {'t': '2019-11-29T20:00:50Z',
#     'u': 'iv9hhjrk2iv2w7',
#     'n': 'i_answer_update'}],
#   'subject': 'markers vs circles',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 5,
#   'content_snipet': 'in this description it says to add graphical elements. is there a different between a marker and a circle? is it okay if',
#   'modified': '2019-11-29T20:00:50Z',
#   'gd': 1,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-29T02:01:24Z',
#   'status': 'active'},
#  {'fol': 'final_tutorial|',
#   'm': 1575166709676,
#   'rq': 0,
#   'id': 'k3izxakoy68212',
#   'unique_views': 102,
#   'score': 102.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['final_tutorial'],
#   'nr': 531,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-28T17:32:40Z', 'u': 'j9ab71s5o5d2hm', 'n': 'create'},
#    {'t': '2019-12-01T02:18:29Z', 'n': 's_answer'}],
#   'subject': 'Final Tutorial Group',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I haven&#39;t started the final tutorial and was looking for a group to do it in. If anyone is in the same spot as me, m',
#   'modified': '2019-12-01T02:18:29Z',
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['final_tutorial', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-28T17:32:40Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575057829385,
#   'rq': 0,
#   'id': 'k3ibarcfk275if',
#   'unique_views': 110,
#   'score': 110.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 530,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-28T06:03:17Z', 'n': 'create'},
#    {'t': '2019-11-29T20:03:49Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'More Info about the data?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Is there a link to information about this data? Like what do all of the abbreviations of race stand for?\n\n',
#   'modified': '2019-11-29T20:03:49Z',
#   'gd': 5,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'tag_good_prof': 1,
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-28T06:03:17Z',
#   'status': 'active'},
#  {'fol': 'project|logistics|',
#   'm': 1575056991985,
#   'rq': 0,
#   'id': 'k3hko3drqb368',
#   'unique_views': 132,
#   'score': 132.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project', 'logistics'],
#   'nr': 529,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-27T17:37:50Z', 'n': 'create'},
#    {'t': '2019-11-27T23:52:15Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'},
#    {'t': '2019-11-29T19:35:09Z', 'n': 'followup'},
#    {'t': '2019-11-29T19:49:51Z', 'n': 'feedback'}],
#   'subject': 'Can we get an update on the state of the projects?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 14,
#   'content_snipet': 'It just feels like there&#39;s been some radio silence on piazza lately about projects and considering they are 65% of o',
#   'modified': '2019-11-29T19:49:51Z',
#   'gd': 10,
#   'has_i': True,
#   'num_favorites': 1,
#   'tags': ['logistics', 'project', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-27T17:37:50Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1574911108654,
#   'rq': 0,
#   'id': 'k3hklxg5hv81xw',
#   'unique_views': 128,
#   'score': 128.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 528,
#   'main_version': 5,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-27T17:36:09Z', 'n': 'create'},
#    {'t': '2019-11-27T17:39:37Z', 'n': 's_answer'},
#    {'t': '2019-11-27T18:22:57Z', 'n': 'followup'},
#    {'t': '2019-11-28T02:23:40Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'},
#    {'t': '2019-11-28T03:18:28Z',
#     'u': 'iv9hhjrk2iv2w7',
#     'n': 'i_answer_update'}],
#   'subject': 'Cannot view the readme for p4',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': 'So my readme file appears as an HTML or similar structure and I cannot view it.Any suggestions?',
#   'modified': '2019-11-28T03:18:28Z',
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-27T17:36:09Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575296167566,
#   'rq': 0,
#   'id': 'k3hfzq57nd1p8',
#   'unique_views': 97,
#   'score': 97.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 527,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-27T15:26:55Z', 'n': 'create'},
#    {'t': '2019-11-27T15:33:31Z', 'n': 'update'},
#    {'t': '2019-12-02T14:16:07Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Project 4: Number of graphical elements required',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'How many graphical elements do we need to add the map? \n(Ex: would it be enough to just add circles indicating sex/race?',
#   'modified': '2019-12-02T14:16:07Z',
#   'gd': 9,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-27T15:26:55Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1574907862704,
#   'rq': 0,
#   'id': 'k3gh66cr89d5bc',
#   'unique_views': 124,
#   'score': 124.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 525,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T23:12:09Z', 'n': 'create'},
#    {'t': '2019-11-26T23:14:49Z', 'n': 's_answer'},
#    {'t': '2019-11-28T02:24:22Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'Project 4 Could not load data on map',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 5,
#   'content_snipet': 'I think the given dataset is too big that I could not mark location on the folium map, any suggestions for solving this ',
#   'modified': '2019-11-28T02:24:22Z',
#   'gd': 1,
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T23:12:09Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1575295938268,
#   'rq': 0,
#   'id': 'k3fmkpheyam4a7',
#   'unique_views': 122,
#   'score': 122.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 523,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T08:55:39Z', 'n': 'create'},
#    {'t': '2019-12-02T14:12:18Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Points distribution for project 3',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'What is the points distribution for project 3?\xa0 Since it is unlikely that project 3 will be officially graded before the',
#   'modified': '2019-12-02T14:12:18Z',
#   'gd': 7,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T08:55:39Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574740697466,
#   'rq': 0,
#   'id': 'k3fbyanutx7eo',
#   'unique_views': 110,
#   'score': 110.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 519,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T03:58:17Z', 'n': 'create'}],
#   'subject': 'Submitting csv file?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'For now the project submission on elms only accepts .ipynb files, could you open up to csv file as well so we can submit',
#   'modified': '2019-11-26T03:58:17Z',
#   'gd': 2,
#   'num_favorites': 0,
#   'tags': ['project3', 'student', 'unanswered'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 1,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-26T03:58:17Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574739530386,
#   'rq': 0,
#   'id': 'k3falpkjtc22e2',
#   'unique_views': 148,
#   'score': 148.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 518,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T03:20:30Z', 'n': 'create'},
#    {'t': '2019-11-26T03:37:05Z', 'u': 'if15rrwundl71u', 'n': 'followup'},
#    {'t': '2019-11-26T03:38:21Z', 'u': 'if15rrwundl71u', 'n': 'feedback'}],
#   'subject': 'How heavy is the Try it out part?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student', 'unanswered'],
#   'gd_f': 0,
#   'content_snipet': 'like 10% of the project 3?',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-11-26T03:38:50Z',
#   'gd': 11,
#   'updated': '2019-11-26T03:20:30Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574737872058,
#   'rq': 0,
#   'id': 'k3fa9qkat0yo',
#   'unique_views': 109,
#   'score': 109.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 517,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T03:11:12Z', 'n': 'create'}],
#   'subject': 'How can estimate errors?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student', 'unanswered'],
#   'gd_f': 0,
#   'content_snipet': 'I&#39;m so confused by the requirement of reporting error estimate. Is there any kind of function in sklearn we can use ',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-11-26T03:11:12Z',
#   'gd': 4,
#   'updated': '2019-11-26T03:11:12Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574737907216,
#   'rq': 0,
#   'id': 'k3f7c507zq82i',
#   'unique_views': 148,
#   'score': 148.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 516,
#   'main_version': 5,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T01:49:05Z', 'u': 'if15rrwundl71u', 'n': 'create'},
#    {'t': '2019-11-26T02:03:45Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-26T02:03:56Z',
#     'u': 'idx3g94pfq357h',
#     'n': 'i_answer_update'},
#    {'t': '2019-11-26T02:20:33Z', 'n': 'followup'},
#    {'t': '2019-11-26T03:11:47Z', 'n': 'feedback'}],
#   'subject': 'cross validation and paired ttests',
#   'no_answer_followup': 1,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I read &#64;458 but I don&#39;t think it quite answers this.\n\nI get that we are doing 10-fold CV, and we want scores for',
#   'modified': '2019-11-26T03:11:47Z',
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T01:49:05Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574739397670,
#   'rq': 0,
#   'id': 'k3f74rjeg5to',
#   'unique_views': 115,
#   'score': 115.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 515,
#   'main_version': 6,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T01:43:21Z', 'n': 'create'},
#    {'t': '2019-11-26T01:51:59Z', 'u': 'if15rrwundl71u', 'n': 's_answer'},
#    {'t': '2019-11-26T01:53:16Z', 'n': 'followup'},
#    {'t': '2019-11-26T01:57:51Z', 'u': 'if15rrwundl71u', 'n': 'feedback'},
#    {'t': '2019-11-26T03:28:35Z', 'n': 'feedback'},
#    {'t': '2019-11-26T03:36:37Z', 'u': 'if15rrwundl71u', 'n': 'feedback'}],
#   'subject': 'hyperparameters clarification',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'so, if i do 10 fold CV on some algorithm, and record accuracies, i would ideally choose the hyperparameters that give th',
#   'modified': '2019-11-26T03:36:37Z',
#   'gd': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T01:43:21Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574731940483,
#   'rq': 0,
#   'id': 'k3f6k7tk7kl2oi',
#   'unique_views': 134,
#   'score': 134.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 514,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T01:27:22Z', 'n': 'create'},
#    {'t': '2019-11-26T01:32:20Z', 'n': 's_answer'}],
#   'subject': 'Resubmitting',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Are we allowed to resubmit the project multiple times? In order to correct a mistake we made earlier for example.',
#   'modified': '2019-11-26T01:32:20Z',
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T01:27:22Z',
#   'status': 'active'},
#  {'fol': 'project2|',
#   'm': 1574727691542,
#   'rq': 0,
#   'id': 'k3f47j86kg22g7',
#   'unique_views': 155,
#   'score': 155.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project2'],
#   'nr': 513,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T00:21:31Z', 'n': 'create'}],
#   'subject': 'Project 2 Grades?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project2', 'student', 'unanswered'],
#   'gd_f': 0,
#   'content_snipet': 'Bumping &#64;472. Thanks =)',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-11-26T00:21:31Z',
#   'gd': 3,
#   'updated': '2019-11-26T00:21:31Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574732289542,
#   'rq': 0,
#   'id': 'k3f43v8uzep15s',
#   'unique_views': 135,
#   'score': 135.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'has_i': True,
#   'folders': ['project3'],
#   'nr': 512,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T00:18:40Z', 'n': 'create'},
#    {'t': '2019-11-26T00:25:13Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-26T00:34:58Z', 'n': 'followup'},
#    {'t': '2019-11-26T01:38:09Z', 'n': 'update'}],
#   'subject': 'deleted',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'content_snipet': 'deleted',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-11-26T01:38:09Z',
#   'updated': '2019-11-26T00:18:40Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574735205278,
#   'rq': 0,
#   'id': 'k3f422l77cf4p5',
#   'unique_views': 134,
#   'score': 134.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'has_i': True,
#   'folders': ['project3'],
#   'nr': 511,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T00:17:16Z', 'n': 'create'},
#    {'t': '2019-11-26T00:25:55Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-26T02:26:45Z', 'u': 'jjikbccza9671h', 'n': 'followup'}],
#   'subject': 'Try it out classification or regression',
#   'no_answer_followup': 1,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'content_snipet': 'The Readme says that you could either do classification or regression. However, I&#39;ve seen on piazza that you need cl',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-11-26T02:26:45Z',
#   'updated': '2019-11-26T00:17:16Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574726712138,
#   'rq': 0,
#   'id': 'k3f2riupgbv4oj',
#   'unique_views': 134,
#   'score': 134.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 510,
#   'main_version': 5,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T23:41:04Z', 'n': 'create'},
#    {'t': '2019-11-25T23:51:39Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-25T23:57:23Z', 'n': 'followup'},
#    {'t': '2019-11-25T23:58:55Z', 'u': 'idx3g94pfq357h', 'n': 'feedback'},
#    {'t': '2019-11-26T00:05:12Z', 'n': 'feedback'}],
#   'subject': 'graph for part 3',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Can someone let me know which graph is correct? Is the graph for the logistic regression for gradient descent supposed t',
#   'modified': '2019-11-26T00:05:12Z',
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-25T23:41:04Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574724536188,
#   'rq': 0,
#   'id': 'k3f26uujksx5hk',
#   'unique_views': 132,
#   'score': 132.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 509,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T23:25:00Z', 'n': 'create'},
#    {'t': '2019-11-25T23:28:56Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'}],
#   'subject': 'Part 2 Problem 3',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Hi, I&#39;m very confused as to how to apply the formulas under problem 1 to problem 3 in order to implement the gradien',
#   'modified': '2019-11-25T23:28:56Z',
#   'gd': 2,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 1,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T23:25:00Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574725651303,
#   'rq': 0,
#   'id': 'k3f1di1nmxl6ig',
#   'unique_views': 130,
#   'score': 130.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'has_i': True,
#   'folders': ['project3'],
#   'nr': 507,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T23:02:11Z', 'n': 'create'},
#    {'t': '2019-11-25T23:47:31Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Do we have to write the cross-validation function ourselves?',
#   'no_answer_followup': 0,
#   'num_favorites': 1,
#   'type': 'question',
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'content_snipet': 'Or can we just make our own class for our logistic regression code, give it a fit and predict function, and use a pre-bu',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-11-25T23:47:31Z',
#   'updated': '2019-11-25T23:02:11Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1574818803746,
#   'rq': 0,
#   'id': 'k3ewhwvuhi25r0',
#   'unique_views': 153,
#   'score': 153.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['other'],
#   'nr': 505,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T20:45:38Z', 'u': 'hcjqqmhat2i461', 'n': 'create'},
#    {'t': '2019-11-25T22:41:17Z', 'n': 'followup'},
#    {'t': '2019-11-27T01:40:03Z', 'u': 'hcjqqmhat2i461', 'n': 'feedback'}],
#   'subject': 'Cancelling my 10am-12pm office hours on Wednesday, Nov 27',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'other'],
#   'gd_f': 0,
#   'content_snipet': 'I&#39;m cancelling my office hours on Wednesday morning since I assume no one will show up on a day right after a projec',
#   'view_adjust': 0,
#   'modified': '2019-11-27T01:40:03Z',
#   'updated': '2019-11-25T20:45:38Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574820327452,
#   'rq': 0,
#   'id': 'k3ew8r21pgr3p6',
#   'unique_views': 204,
#   'score': 204.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 504,
#   'main_version': 62,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T20:38:31Z', 'n': 'create'},
#    {'t': '2019-11-25T21:02:05Z', 'n': 'update'},
#    {'t': '2019-11-25T21:15:59Z', 'n': 's_answer'},
#    {'t': '2019-11-25T21:16:20Z', 'n': 'followup'},
#    {'t': '2019-11-25T21:53:39Z', 'n': 'followup'},
#    {'t': '2019-11-25T21:56:06Z', 'n': 'feedback'},
#    {'t': '2019-11-25T21:56:50Z', 'n': 'feedback'},
#    {'t': '2019-11-25T22:05:01Z', 'n': 'followup'},
#    {'t': '2019-11-25T22:10:09Z', 'u': 'jlgkhem7a006ij', 'n': 'followup'},
#    {'t': '2019-11-25T22:12:38Z', 'n': 'feedback'},
#    {'t': '2019-11-25T22:12:40Z', 'n': 'feedback'},
#    {'t': '2019-11-25T22:55:02Z', 'n': 'feedback'},
#    {'t': '2019-11-25T23:41:04Z', 'n': 'feedback'},
#    {'t': '2019-11-25T23:41:30Z', 'n': 'feedback'},
#    {'t': '2019-11-25T23:41:42Z', 'n': 'followup'},
#    {'t': '2019-11-25T23:46:34Z', 'u': 'jsm892641aymp', 'n': 'feedback'},
#    {'t': '2019-11-26T00:14:26Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:14:40Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:14:47Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:15:41Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:16:13Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:16:30Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:17:09Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:17:44Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:22:00Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:23:12Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:28:34Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:35:06Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:41:51Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:45:03Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:47:56Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:47:59Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:02Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:06Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:20Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:31Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:39Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:50:32Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:54:24Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:58:22Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:59:00Z', 'n': 'feedback'},
#    {'t': '2019-11-26T01:02:20Z', 'n': 'feedback'},
#    {'t': '2019-11-26T01:02:55Z', 'n': 'feedback'},
#    {'t': '2019-11-26T01:16:54Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:18:43Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:19:31Z', 'n': 'feedback'},
#    {'t': '2019-11-26T01:19:41Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:23:01Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:23:38Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:24:58Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:26:32Z', 'u': 'jrh3tnn73fw8r', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:28:01Z', 'u': 'jrh3tnn73fw8r', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:31:56Z', 'u': 'jrz96gwn7f66ak', 'n': 'followup'},
#    {'t': '2019-11-26T01:58:43Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T02:18:02Z', 'n': 'feedback'},
#    {'t': '2019-11-26T02:32:21Z', 'n': 'followup'},
#    {'t': '2019-11-26T02:35:38Z', 'n': 'feedback'},
#    {'t': '2019-11-26T03:07:58Z', 'n': 'feedback'},
#    {'t': '2019-11-26T03:13:00Z', 'n': 'feedback'},
#    {'t': '2019-11-26T05:26:25Z', 'n': 'followup'},
#    {'t': '2019-11-26T05:35:43Z', 'n': 'followup'},
#    {'t': '2019-11-27T02:05:27Z', 'n': 'followup'}],
#   'subject': 'One Last Extension Please?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 32,
#   'content_snipet': 'There are so many people in office hours, and it is much more difficult than other projects, so could you please give on',
#   'modified': '2019-11-27T02:05:27Z',
#   'gd': 73,
#   'has_s': True,
#   'num_favorites': 3,
#   'tags': ['project3', 'student'],
#   'tag_good_prof': 1,
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T20:38:31Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574721917718,
#   'rq': 0,
#   'id': 'k3ev2dnfpht1kn',
#   'unique_views': 151,
#   'score': 151.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 502,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T20:05:34Z', 'n': 'create'},
#    {'t': '2019-11-25T22:45:17Z', 'n': 's_answer'}],
#   'subject': 'Project 3 Rubric',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Will we be given a rubric for Project 3?',
#   'modified': '2019-11-25T22:45:17Z',
#   'gd': 9,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T20:05:34Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574718009244,
#   'rq': 0,
#   'id': 'k3eutmq2qy95yq',
#   'unique_views': 169,
#   'score': 169.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 501,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T19:58:46Z', 'n': 'create'},
#    {'t': '2019-11-25T21:39:13Z', 'u': 'jle6g1r73v07pa', 'n': 's_answer'},
#    {'t': '2019-11-25T21:40:09Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Dataset for &#34;Try it out&#34;',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': 'Can we use the dataset used in part 1 for the &#34;Try it out&#34; Section?\xa0\n\nThank you!\xa0',
#   'modified': '2019-11-25T21:40:09Z',
#   'gd': 1,
#   'has_i': True,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T19:58:46Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574717941494,
#   'rq': 0,
#   'id': 'k3etz0a6i4y5rv',
#   'unique_views': 134,
#   'score': 134.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'has_i': True,
#   'folders': ['project3'],
#   'nr': 500,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T19:34:57Z', 'n': 'create'},
#    {'t': '2019-11-25T21:39:01Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Can I use GridSearchCV to find best parameters?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'content_snipet': '',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-11-25T21:39:01Z',
#   'updated': '2019-11-25T19:34:57Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574721564071,
#   'rq': 0,
#   'id': 'k3esa5m5m4i6xc',
#   'unique_views': 132,
#   'score': 132.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 499,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T18:47:38Z', 'n': 'create'},
#    {'t': '2019-11-25T21:43:36Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-25T22:39:24Z', 'n': 's_answer'}],
#   'subject': 'Siting sources for the derivation of part 2',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 3,
#   'content_snipet': 'Are we allowed to use other sources to figure out the derivation of the update equation?',
#   'modified': '2019-11-25T22:39:24Z',
#   'has_i': True,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-25T18:47:38Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1574707858057,
#   'rq': 0,
#   'id': 'k3ersb3o85p34s',
#   'unique_views': 180,
#   'score': 180.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 498,
#   'main_version': 7,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T18:33:45Z', 'n': 'create'},
#    {'t': '2019-11-25T18:34:46Z', 'n': 's_answer'},
#    {'t': '2019-11-25T18:38:02Z', 'n': 'followup'},
#    {'t': '2019-11-25T18:38:36Z', 'n': 's_answer_update'},
#    {'t': '2019-11-25T18:39:52Z', 'u': 'j6wriis2x1oic', 'n': 's_answer_update'},
#    {'t': '2019-11-25T18:46:38Z', 'n': 'feedback'},
#    {'t': '2019-11-25T18:50:58Z', 'n': 'feedback'}],
#   'subject': 'TA not here',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Saeed not here for his office hours. Considering the project is due today, this is unacceptable. At least someone should',
#   'modified': '2019-11-25T18:50:58Z',
#   'gd': 3,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 1,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-25T18:33:45Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574707705445,
#   'rq': 0,
#   'id': 'k3erhrju7u919l',
#   'unique_views': 150,
#   'score': 150.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 497,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T18:25:33Z', 'n': 'create'},
#    {'t': '2019-11-25T18:26:28Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'},
#    {'t': '2019-11-25T18:26:52Z', 'n': 'followup'},
#    {'t': '2019-11-25T18:48:25Z', 'u': 'idx3g94pfq357h', 'n': 'feedback'}],
#   'subject': 'What is the loss function for logistic gradient descent?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Question in title; thanks!',
#   'modified': '2019-11-25T18:48:25Z',
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T18:25:33Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574704287516,
#   'rq': 0,
#   'id': 'k3ep59apq3w4fm',
#   'unique_views': 129,
#   'score': 129.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 496,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T17:19:51Z', 'n': 'create'},
#    {'t': '2019-11-25T17:51:27Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'External Source Use',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'If we use outside sources to help write our code for the multiple logistic regression, should we cite them in a comment ',
#   'modified': '2019-11-25T17:51:27Z',
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T17:19:51Z',
#   'status': 'active'},
#  {'fol': 'exam|',
#   'm': 1574800284217,
#   'rq': 0,
#   'id': 'k3emy8747mv3qw',
#   'unique_views': 133,
#   'score': 133.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['exam'],
#   'nr': 495,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T16:18:23Z', 'n': 'create'},
#    {'t': '2019-11-25T19:27:35Z', 'u': 'jrgrxaenjy9t5', 'n': 'i_answer'},
#    {'t': '2019-11-26T20:28:43Z', 'n': 's_answer'},
#    {'t': '2019-11-26T20:31:24Z', 'n': 'followup'}],
#   'subject': 'Exam: Multiple Choice Confusion',
#   'no_answer_followup': 1,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': '\nFor question 2b (the correct answer was iii) I circled 2 answers. Since I circled the right answer and 1 wrong answer, ',
#   'modified': '2019-11-26T20:31:24Z',
#   'gd': 2,
#   'has_i': True,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['exam', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-25T16:18:23Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574701311117,
#   'rq': 0,
#   'id': 'k3e8ttypn5c5lj',
#   'unique_views': 148,
#   'score': 148.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 494,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T09:43:04Z', 'n': 'create'},
#    {'t': '2019-11-25T17:01:51Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Dataset',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Since we&#39;re using our logistic regression, should our dataset for the try it out section only have 2 categories?',
#   'modified': '2019-11-25T17:01:51Z',
#   'gd': 1,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
# ...
#    {'t': '2019-08-29T21:46:10Z', 'n': 'followup'},
#    {'t': '2019-08-29T22:34:16Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-08-29T22:35:26Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-09-10T04:44:04Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'update'}],
#   'subject': 'Quiz #1 is Live!',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'other'],
#   'content_snipet': 'Quiz 1 is now live on ELMS.\xa0 I&#39;ve also just pushed the supporting Jupyter Notebook to the public Github repository (',
#   'view_adjust': 0,
#   'modified': '2019-09-10T04:44:04Z',
#   'updated': '2019-08-29T20:15:31Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1567092792894,
#   'rq': 0,
#   'id': 'jzw6odpkrrb25h',
#   'unique_views': 168,
#   'score': 168.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 19,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T04:23:52Z', 'n': 'create'},
#    {'t': '2019-08-29T15:33:12Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'TA office hours',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'When will TA office hours be posted? I&#39;m having trouble with docker and was planning to go to office hours.',
#   'modified': '2019-08-29T15:33:12Z',
#   'gd': 2,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['other', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-29T04:23:52Z',
#   'status': 'active'},
#  {'fol': 'project|',
#   'm': 1567112675272,
#   'rq': 0,
#   'id': 'jzw673pqlxt59g',
#   'unique_views': 206,
#   'score': 206.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['project'],
#   'nr': 18,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T04:10:26Z', 'n': 'create'},
#    {'t': '2019-08-29T14:21:49Z', 'n': 's_answer'},
#    {'t': '2019-08-29T21:04:35Z', 'n': 'followup'}],
#   'subject': 'Jupyter Notebook',
#   'no_answer_followup': 1,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Got to the part\xa0 in the doc where I&#39;m entering the command:\n\ndocker run -it -v PWD/project0/home/jovyan/notebooks --',
#   'modified': '2019-08-29T21:04:35Z',
#   'gd': 2,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-29T04:10:26Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1572983645544,
#   'rq': 0,
#   'id': 'jzw5179dohl3ca',
#   'unique_views': 269,
#   'score': 269.0,
#   'is_new': False,
#   'version': 1,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 17,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T03:37:51Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-05T19:54:05Z', 'u': 'jrgrxaenjy9t5', 'n': 'update'}],
#   'subject': 'Piazza Best Practices',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'other'],
#   'content_snipet': 'If folks post a question on Piazza, and that question is answered,\xa0please\xa0update your post with how you solved that prob',
#   'view_adjust': 0,
#   'modified': '2019-11-05T19:54:05Z',
#   'gd': 3,
#   'updated': '2019-08-29T03:37:51Z',
#   'status': 'active'},
#  {'fol': 'logistics|',
#   'm': 1567047168106,
#   'rq': 0,
#   'id': 'jzw3539mqmu3ek',
#   'unique_views': 198,
#   'score': 198.0,
#   'is_new': False,
#   'version': 3,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['logistics'],
#   'nr': 16,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T02:44:53Z', 'n': 'create'},
#    {'t': '2019-08-29T02:50:54Z', 'n': 'update'},
#    {'t': '2019-08-29T02:52:48Z', 'n': 'update'}],
#   'subject': 'Is Docker a Requirement?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['logistics', 'student', 'unanswered'],
#   'content_snipet': 'I have a really slow and old Windows computer and I cannot figure out how to make Docker work. Can I just get a list of ',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-08-29T02:52:48Z',
#   'gd': 3,
#   'updated': '2019-08-29T02:44:53Z',
#   'status': 'active'},
#  {'fol': 'project|',
#   'm': 1567112320748,
#   'rq': 0,
#   'id': 'jzw0pgt4r8f545',
#   'unique_views': 205,
#   'score': 205.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['project'],
#   'nr': 15,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T01:36:45Z', 'n': 'create'},
#    {'t': '2019-08-29T02:58:51Z', 'u': 'j79r0cp61395ue', 'n': 's_answer'},
#    {'t': '2019-08-29T04:40:12Z', 'n': 'followup'},
#    {'t': '2019-08-29T20:58:40Z', 'u': 'jlgkhlh2usf6og', 'n': 'feedback'}],
#   'subject': 'Jupyter Setup with Docker',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I set up Docker correctly but when I try to run the command to set up the notebooks after everything has downloaded, I g',
#   'modified': '2019-08-29T20:58:40Z',
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-08-29T01:36:45Z',
#   'status': 'active'},
#  {'fol': 'logistics|',
#   'm': 1570339657301,
#   'rq': 0,
#   'id': 'jzvqsybkhix2nw',
#   'unique_views': 184,
#   'score': 184.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['logistics'],
#   'nr': 14,
#   'main_version': 12,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T20:59:31Z', 'u': 'jzubd7n5asc3kp', 'n': 'create'},
#    {'t': '2019-08-29T01:29:46Z', 'n': 's_answer'},
#    {'t': '2019-08-29T02:22:18Z', 'u': 'jzu83lw5k6o20g', 'n': 'followup'},
#    {'t': '2019-08-29T03:52:05Z', 'u': 'j6wriis2x1oic', 'n': 'feedback'},
#    {'t': '2019-08-29T13:50:03Z', 'u': 'jzubd7n5asc3kp', 'n': 'feedback'},
#    {'t': '2019-08-29T20:35:19Z', 'n': 'followup'},
#    {'t': '2019-08-29T21:42:10Z', 'u': 'jzubd7n5asc3kp', 'n': 'feedback'},
#    {'t': '2019-08-30T01:20:25Z', 'u': 'j6xuc2iutt72ad', 'n': 'feedback'},
#    {'t': '2019-08-30T03:45:12Z', 'u': 'j6xuc2iutt72ad', 'n': 'feedback'},
#    {'t': '2019-08-30T04:37:05Z', 'n': 'feedback'},
#    {'t': '2019-08-30T18:45:56Z', 'n': 'feedback'},
#    {'t': '2019-10-06T05:27:37Z', 'n': 'followup'}],
#   'subject': 'No notebooks in notebooks folder',
#   'no_answer_followup': 3,
#   'has_s': True,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['logistics', 'student'],
#   'content_snipet': 'When I open\xa0the notebooks folder, there aren&#39;t any notebooks there.\xa0Did I make an error during some part of the setu',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-10-06T05:27:37Z',
#   'gd': 9,
#   'updated': '2019-08-28T20:59:31Z',
#   'status': 'active'},
#  {'fol': 'logistics|',
#   'm': 1567443898415,
#   'rq': 0,
#   'id': 'jzvqm9h0h3s45f',
#   'unique_views': 171,
#   'score': 171.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['logistics'],
#   'nr': 13,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T20:54:19Z', 'n': 'create'},
#    {'t': '2019-09-02T02:18:51Z', 'n': 'followup'},
#    {'t': '2019-09-02T17:04:41Z', 'n': 'feedback'},
#    {'t': '2019-09-02T17:04:58Z', 'n': 's_answer'}],
#   'subject': 'Launched Jupyter but can only see a &#39;Work&#39; folder',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Can&#39;t seem to find the notebooks directory as I have a single folder named Work.\n\nWhen I copied the command to termi',
#   'modified': '2019-09-02T17:04:58Z',
#   'gd': 9,
#   'has_s': True,
#   'num_favorites': 1,
#   'tags': ['logistics', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-28T20:54:19Z',
#   'status': 'active'},
#  {'fol': 'logistics|',
#   'm': 1567026093496,
#   'rq': 0,
#   'id': 'jzvlujir5h62v7',
#   'unique_views': 184,
#   'score': 184.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['logistics'],
#   'nr': 12,
#   'main_version': 9,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T18:40:47Z', 'n': 'create'},
#    {'t': '2019-08-28T18:44:22Z', 'n': 's_answer'},
#    {'t': '2019-08-28T18:46:58Z', 'n': 'followup'},
#    {'t': '2019-08-28T18:58:01Z', 'n': 'feedback'},
#    {'t': '2019-08-28T19:06:57Z', 'n': 'feedback'},
#    {'t': '2019-08-28T19:47:24Z', 'n': 'feedback'},
#    {'t': '2019-08-28T19:49:50Z', 'n': 'feedback'},
#    {'t': '2019-08-28T20:00:04Z', 'n': 'feedback'},
#    {'t': '2019-08-28T21:01:33Z', 'n': 'feedback'}],
#   'subject': 'Difficulty Setting Up Notebook',
#   'no_answer_followup': 0,
#   'has_s': True,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['logistics', 'student'],
#   'content_snipet': 'I believe I&#39;ve cloned the class repo and gotten Docker installed and running, but when I go to start a Jupyter Noteb',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-08-28T21:01:33Z',
#   'updated': '2019-08-28T18:40:47Z',
#   'status': 'active'},
#  {'fol': 'project|',
#   'm': 1567108097023,
#   'rq': 0,
#   'id': 'jzvjzojohex4b9',
#   'unique_views': 201,
#   'score': 201.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['project'],
#   'nr': 11,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T17:48:48Z', 'n': 'create'},
#    {'t': '2019-08-29T19:48:17Z', 'u': 'j8neqb407vv1uz', 'n': 's_answer'}],
#   'subject': 'Connecting to the Jupyter Notebook',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 4,
#   'content_snipet': 'I used the Docker Toolbox thing to set up Docker as described by the students&#39; answer in &#64;7. Everything seemed t',
#   'modified': '2019-08-29T19:48:17Z',
#   'gd': 7,
#   'has_s': True,
#   'num_favorites': 1,
#   'tags': ['project', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-28T17:48:48Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1567517562427,
#   'rq': 0,
#   'id': 'jzvhw9dkj507f0',
#   'unique_views': 184,
#   'score': 184.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 10,
#   'main_version': 6,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T16:50:09Z', 'u': 'jrhgoaszdc45x1', 'n': 'create'},
#    {'t': '2019-08-28T17:16:27Z', 'u': 'jrhgoaszdc45x1', 'n': 'update'},
#    {'t': '2019-08-29T03:39:23Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'followup'},
#    {'t': '2019-08-29T03:44:00Z', 'u': 'j6wriis2x1oic', 'n': 'feedback'},
#    {'t': '2019-09-03T13:03:48Z', 'u': 'jrhgoaszdc45x1', 'n': 'feedback'},
#    {'t': '2019-09-03T13:32:42Z', 'u': 'j6wriis2x1oic', 'n': 'feedback'}],
#   'subject': 'Is anyone else&#39;s project 0 code filled with syntax errors?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['other', 'student', 'unanswered'],
#   'content_snipet': 'I&#39;m fiddling around with the notebook as per the instructions and I keep getting errors on the basic syntax of the c',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-09-03T13:32:42Z',
#   'gd': 1,
#   'updated': '2019-08-28T16:50:09Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1567006170531,
#   'rq': 0,
#   'id': 'jzveukremfk37h',
#   'unique_views': 203,
#   'score': 203.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 9,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T15:24:52Z', 'n': 'create'},
#    {'t': '2019-08-28T15:28:49Z', 'n': 's_answer'},
#    {'t': '2019-08-28T15:29:30Z', 'n': 's_answer_update'}],
#   'subject': 'Jupyter Notebook',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'The instructions say to replace PWD with the path to the git directory for the command line:\ndocker run -it -v PWD/proje',
#   'modified': '2019-08-28T15:29:30Z',
#   'gd': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['other', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-08-28T15:24:52Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1566966877405,
#   'rq': 0,
#   'id': 'jzurl4q7nmc4ge',
#   'unique_views': 176,
#   'score': 176.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 8,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T04:33:40Z', 'u': 'jlgkhqea1gz6s1', 'n': 'create'},
#    {'t': '2019-08-28T04:34:37Z', 'u': 'jlgkhqea1gz6s1', 'n': 'update'}],
#   'subject': 'ProPublica&#39;s Analysis of the COMPAS Algorithm',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['other', 'student', 'unanswered'],
#   'tag_good_prof': 1,
#   'content_snipet': 'Hey y&#39;all! \xa0\n\nDuring today&#39;s lecture, I mentioned a ProPublica study about how COMPAS, a tool used by judges, pr',
#   'view_adjust': 0,
#   'modified': '2019-08-28T04:34:37Z',
#   'd-bucket': 'Yesterday',
#   'gd': 3,
#   'updated': '2019-08-28T04:33:40Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1567011397874,
#   'rq': 0,
#   'id': 'jzuit4bewc9a1',
#   'unique_views': 221,
#   'score': 221.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 7,
#   'main_version': 7,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T00:27:56Z', 'n': 'create'},
#    {'t': '2019-08-28T01:14:53Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'},
#    {'t': '2019-08-28T01:44:34Z', 'n': 's_answer'},
#    {'t': '2019-08-28T01:45:58Z',
#     'u': 'jlgkhrb24v66sm',
#     'n': 's_answer_update'},
#    {'t': '2019-08-28T01:46:04Z', 'n': 's_answer_update'},
#    {'t': '2019-08-28T14:44:40Z',
#     'u': 'iv9hhjrk2iv2w7',
#     'n': 'i_answer_update'},
#    {'t': '2019-08-28T16:56:37Z', 'n': 'followup'}],
#   'subject': 'Pro or Enterprise Version required?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I am attempting to download Docker for Windows 10 from this link (https://hub.docker.com/?overlay=onboarding), however i',
#   'modified': '2019-08-28T16:56:37Z',
#   'gd': 3,
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 1,
#   'tags': ['other', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-08-28T00:27:56Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1566937674374,
#   'rq': 0,
#   'id': 'jzu72r4ggz81or',
#   'unique_views': 221,
#   'score': 221.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 6,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-27T18:59:30Z', 'n': 'create'},
#    {'t': '2019-08-27T18:59:54Z', 'n': 'update'},
#    {'t': '2019-08-27T19:55:09Z', 'u': 'if15rrwundl71u', 'n': 's_answer'},
#    {'t': '2019-08-27T20:27:54Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'Elms?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 6,
#   'content_snipet': 'Is the elms ready yet?I did not see 320 in my elms.',
#   'modified': '2019-08-27T20:27:54Z',
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['other', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-27T18:59:30Z',
#   'status': 'active'},
#  {'fol': '',
#   'm': 1566428620181,
#   'rq': 0,
#   'id': 'jzlv5ms5w434u1',
#   'unique_views': 157,
#   'score': 157.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/18 - 8/24',
#   'bucket_order': 20,
#   'folders': [],
#   'nr': 1,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-21T23:03:40Z', 'u': 'gd6v7134AUa', 'n': 'create'}],
#   'subject': 'Welcome to Piazza!',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['student'],
#   'content_snipet': "\nPiazza is a Q&A platform designed to get you great answers from classmates and instructors fast. We've put together thi",
#   'view_adjust': 0,
#   'modified': '2019-08-21T23:03:40Z',
#   'updated': '2019-08-21T23:03:40Z',
#   'status': 'active'}]

# %% [markdown]
# Now we need to decide what kind of data we want to save about each post. The data we want is as follows:
# - posted : date and time
# - folders : list string
# - type : string
# - subject : string
# - total_replies : int
# - instructor_replies : int
# - unique_views : int
# - num_favorites : int

# %%
folders = class_data['tags']['instructor']
folders
# Out:
# ['quiz1',
#  'quiz2',
#  'quiz3',
#  'quiz4',
#  'quiz5',
#  'quiz6',
#  'quiz7',
#  'quiz8',
#  'quiz9',
#  'quiz10',
#  'quiz11',
#  'quiz12',
#  'project1',
#  'project2',
#  'project3',
#  'project4',
#  'midterm_exam',
#  'final_tutorial',
#  'other',
#  'project',
#  'exam',
#  'logistics']

# %%
posts_dict
# Out:
# [{'fol': 'project4|',
#   'pin': 1,
#   'm': 1575313343571,
#   'rq': 0,
#   'id': 'k3osw3839eu1f6',
#   'unique_views': 48,
#   'score': 48.0,
#   'is_new': False,
#   'version': 1,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['project4'],
#   'nr': 551,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T19:02:23Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'}],
#   'subject': 'Project 4 Key',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'pin', 'project4'],
#   'gd_f': 0,
#   'content_snipet': 'In a previous class, a student had experience operating on the type of data used in P4; she wrote the following, which I',
#   'view_adjust': 0,
#   'modified': '2019-12-02T19:02:23Z',
#   'gd': 1,
#   'updated': '2019-12-02T19:02:23Z',
#   'status': 'active'},
#  {'fol': 'midterm_exam|',
#   'pin': 1,
#   'm': 1574268981850,
#   'rq': 0,
#   'id': 'k35zogl87lw5nx',
#   'unique_views': 259,
#   'score': 259.0,
#   'is_new': True,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['midterm_exam'],
#   'nr': 429,
#   'main_version': 11,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-19T15:04:47Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-19T15:06:11Z', 'n': 'followup'},
#    {'t': '2019-11-19T15:07:52Z', 'u': 'ikq4ua6j9dp38z', 'n': 'followup'},
#    {'t': '2019-11-19T15:09:04Z', 'n': 'feedback'},
#    {'t': '2019-11-19T15:10:12Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-19T15:10:24Z', 'u': 'jl3b2jmi38z3wh', 'n': 'followup'},
#    {'t': '2019-11-19T15:20:37Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-19T15:23:35Z', 'u': 'jm6ikg6z5m81e2', 'n': 'followup'},
#    {'t': '2019-11-19T17:12:04Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-19T18:05:54Z', 'u': 'j6rz1px06pl629', 'n': 'feedback'},
#    {'t': '2019-11-20T16:56:21Z', 'n': 'feedback'}],
#   'subject': 'Midterm grades posted',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'midterm_exam', 'pin'],
#   'content_snipet': 'We&#39;ve posted midterm grades on GradeScope.\xa0 A few midterms are missing from those who took the exam via ADS; I&#39;l',
#   'view_adjust': 0,
#   'modified': '2019-11-20T16:56:21Z',
#   'updated': '2019-11-19T15:04:47Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'pin': 1,
#   'm': 1574114977824,
#   'rq': 0,
#   'id': 'k34o5uf2wb63ee',
#   'unique_views': 273,
#   'score': 273.0,
#   'is_new': True,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['project3'],
#   'nr': 423,
#   'main_version': 8,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-18T16:54:37Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-18T16:54:59Z', 'u': 'jl3b2jmi38z3wh', 'n': 'followup'},
#    {'t': '2019-11-18T16:55:33Z', 'n': 'followup'},
#    {'t': '2019-11-18T16:56:31Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'update'},
#    {'t': '2019-11-18T16:59:32Z', 'n': 'followup'},
#    {'t': '2019-11-18T17:00:49Z', 'n': 'followup'},
#    {'t': '2019-11-18T18:46:07Z', 'n': 'followup'},
#    {'t': '2019-11-18T22:09:37Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'}],
#   'subject': 'Extension on Project 3',
#   'no_answer_followup': 0,
#   'num_favorites': 1,
#   'type': 'note',
#   'tags': ['instructor-note', 'pin', 'project3'],
#   'content_snipet': 'I&#39;m extending P3&#39;s due date to next Monday, 11/25.\xa0 This project is a bit chaotic.\n\n(Please\xa0make sure you have s',
#   'view_adjust': 0,
#   'modified': '2019-11-18T22:09:37Z',
#   'gd': 12,
#   'updated': '2019-11-18T16:54:37Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'pin': 1,
#   'm': 1573665516224,
#   'rq': 0,
#   'id': 'k2wi7zmj8t15vc',
#   'unique_views': 281,
#   'score': 281.0,
#   'is_new': False,
#   'version': 3,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['project3'],
#   'nr': 370,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-12T23:46:10Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-13T17:17:41Z', 'n': 'followup'},
#    {'t': '2019-11-13T17:18:36Z', 'n': 'feedback'}],
#   'subject': 'Update to Project 3',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'pin', 'project3'],
#   'content_snipet': 'I&#39;ve updated Project 3 by\xa0removing\xa0Question 7/Exercise 13.\xa0 We&#39;re still running behind, and we won&#39;t get to ',
#   'view_adjust': 0,
#   'modified': '2019-11-13T17:18:36Z',
#   'gd': 1,
#   'updated': '2019-11-12T23:46:10Z',
#   'status': 'active'},
#  {'fol': 'midterm_exam|',
#   'pin': 1,
#   'm': 1574137021210,
#   'rq': 0,
#   'id': 'k25efaof64v6lw',
#   'unique_views': 277,
#   'score': 277.0,
#   'is_new': False,
#   'version': 4,
#   'bucket_name': 'Pinned',
#   'bucket_order': 0,
#   'folders': ['midterm_exam'],
#   'nr': 317,
#   'main_version': 7,
#   'request_instructor': 0,
#   'log': [{'t': '2019-10-25T00:30:05Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-12T18:30:36Z', 'n': 'followup'},
#    {'t': '2019-11-12T19:18:56Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-12T20:11:20Z', 'n': 'feedback'},
#    {'t': '2019-11-18T19:09:04Z', 'n': 'feedback'},
#    {'t': '2019-11-18T22:08:15Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-11-19T04:17:01Z', 'u': 'jzucg56coc25pl', 'n': 'feedback'}],
#   'subject': 'Midterm Follow-Up',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'midterm_exam', 'pin'],
#   'content_snipet': 'Thanks to everyone who sat for today&#39;s midterm!\xa0 I think it went well.\xa0 Just a quick note: we have a few students wh',
#   'view_adjust': 0,
#   'modified': '2019-11-19T04:17:01Z',
#   'updated': '2019-10-25T00:30:05Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575310380835,
#   'rq': 0,
#   'id': 'k3or4l5v3874iq',
#   'unique_views': 31,
#   'score': 31.0,
#   'is_new': True,
#   'bucket_name': 'Today',
#   'bucket_order': 2,
#   'folders': ['project4'],
#   'nr': 550,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T18:13:00Z', 'n': 'create'}],
#   'subject': 'Map not showing on notebook but works on HTML',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project4', 'student', 'unanswered'],
#   'gd_f': 0,
#   'content_snipet': 'I&#39;m about to submit my project but noticed that the map does not show in the notebook but it does show up correctly ',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-12-02T18:13:00Z',
#   'gd': 5,
#   'updated': '2019-12-02T18:13:00Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575262917735,
#   'rq': 0,
#   'id': 'k3nyjeao7fz197',
#   'unique_views': 50,
#   'score': 50.0,
#   'is_new': True,
#   'd-bucket': 'Yesterday',
#   'bucket_name': 'Yesterday',
#   'bucket_order': 3,
#   'folders': ['project4'],
#   'nr': 548,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T04:52:42Z', 'n': 'create'},
#    {'t': '2019-12-02T05:01:57Z', 'u': 'jlci7zk6mz66x7', 'n': 's_answer'}],
#   'subject': 'Notebook crashes when adding many markers',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I&#39;m adding a large number of markers (one for every crime) to the map.\nWhen I attempt to display the map after addin',
#   'modified': '2019-12-02T05:01:57Z',
#   'gd': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-12-02T04:52:42Z',
#   'status': 'active'},
#  {'fol': 'quiz12|',
#   'm': 1575312246299,
#   'rq': 0,
#   'id': 'k3nwrh54w3o58i',
#   'unique_views': 60,
#   'score': 60.0,
#   'is_new': True,
#   'd-bucket': 'Yesterday',
#   'bucket_name': 'Yesterday',
#   'bucket_order': 3,
#   'folders': ['quiz12'],
#   'nr': 547,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T04:03:00Z', 'n': 'create'},
#    {'t': '2019-12-02T18:44:06Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'Reading Quiz 12',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Is there going to be a 12th quiz? If not, are two quizzes still going to be dropped, and are the quizzes still going to ',
#   'modified': '2019-12-02T18:44:06Z',
#   'gd': 1,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['quiz12', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-12-02T04:03:00Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575296781240,
#   'rq': 0,
#   'id': 'k3no8qfn42z6n4',
#   'unique_views': 66,
#   'score': 66.0,
#   'is_new': True,
#   'd-bucket': 'Yesterday',
#   'bucket_name': 'Yesterday',
#   'bucket_order': 3,
#   'folders': ['project4'],
#   'nr': 546,
#   'main_version': 6,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-02T00:04:29Z', 'n': 'create'},
#    {'t': '2019-12-02T00:04:59Z', 'n': 'update'},
#    {'t': '2019-12-02T00:07:47Z', 'n': 'update'},
#    {'t': '2019-12-02T00:08:32Z', 'n': 'update'},
#    {'t': '2019-12-02T00:08:44Z', 'n': 'update'},
#    {'t': '2019-12-02T14:26:21Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Ignore',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Nvmd, resolved',
#   'modified': '2019-12-02T14:26:21Z',
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-12-02T00:04:29Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575258615366,
#   'rq': 0,
#   'id': 'k3nl9gtk6z27c0',
#   'unique_views': 79,
#   'score': 79.0,
#   'is_new': True,
#   'd-bucket': 'Yesterday',
#   'bucket_name': 'Yesterday',
#   'bucket_order': 3,
#   'folders': ['project4'],
#   'nr': 544,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-01T22:41:04Z', 'n': 'create'},
#    {'t': '2019-12-01T22:50:56Z', 'n': 's_answer'},
#    {'t': '2019-12-01T22:52:57Z', 'n': 'followup'},
#    {'t': '2019-12-02T03:50:15Z', 'n': 'feedback'}],
#   'subject': 'Does anyone know what &#39;I&#39; is in the race column?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': 'Also, &#34;A&#34; means asian right?\xa0',
#   'modified': '2019-12-02T03:50:15Z',
#   'gd': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-12-01T22:41:04Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575160686930,
#   'rq': 0,
#   'id': 'k3ma04lukrx1d7',
#   'unique_views': 75,
#   'score': 75.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 543,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-12-01T00:38:06Z', 'n': 'create'}],
#   'subject': 'HeatMapWithTime (probably) not working',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Just a heads up, the HeatMapWithTime folio plugin seems to be broken, so if you&#39;re thinking of using it, it might be',
#   'modified': '2019-12-01T00:38:06Z',
#   'gd': 3,
#   'num_favorites': 0,
#   'tags': ['project4', 'student', 'unanswered'],
#   'tag_good_prof': 1,
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 1,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-12-01T00:38:06Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575227950282,
#   'rq': 0,
#   'id': 'k3m6v2bncvg5n1',
#   'unique_views': 97,
#   'score': 97.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 542,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-30T23:10:11Z', 'n': 'create'},
#    {'t': '2019-11-30T23:12:14Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'},
#    {'t': '2019-12-01T19:19:10Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'What exactly is the &#34;write-up&#34; for project 4? Is it the same thing as the short prose description?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 4,
#   'content_snipet': '',
#   'modified': '2019-12-01T19:19:10Z',
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-30T23:10:11Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575228138830,
#   'rq': 0,
#   'id': 'k3m4smk5bo9761',
#   'unique_views': 83,
#   'score': 83.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 541,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-30T22:12:18Z', 'n': 'create'},
#    {'t': '2019-11-30T22:14:17Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'},
#    {'t': '2019-11-30T22:14:32Z', 'u': 'j6wriis2x1oic', 'n': 's_answer_update'},
#    {'t': '2019-12-01T19:22:18Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'Map won&#39;t show up in jupyter notebook',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I&#39;m trying to mark the location of crime in Jupyter Notebook with circles. However, Jupyter notebook cannot render t',
#   'modified': '2019-12-01T19:22:18Z',
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-30T22:12:18Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575301867616,
#   'rq': 0,
#   'id': 'k3l9rtkkmc46jh',
#   'unique_views': 87,
#   'score': 87.0,
#   'is_new': False,
#   'version': 2,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 540,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-30T07:43:53Z', 'n': 'create'},
#    {'t': '2019-11-30T08:52:41Z', 'n': 's_answer'},
#    {'t': '2019-12-01T21:16:57Z', 'n': 'followup'},
#    {'t': '2019-12-02T15:51:07Z', 'u': 'idx3g94pfq357h', 'n': 'feedback'}],
#   'subject': 'What does &#34;U” represent in race?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': 'In project 4 given dataset race column. U represent which race?',
#   'modified': '2019-12-02T15:51:07Z',
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-30T07:43:53Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575065112750,
#   'rq': 0,
#   'id': 'k3koa7oszki4zu',
#   'unique_views': 103,
#   'score': 103.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 537,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-29T21:42:19Z', 'n': 'create'},
#    {'t': '2019-11-29T22:05:12Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'}],
#   'subject': 'Project 4 Submission Clarification',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': '\n\n\n\nFor project 4, do I only submit the notebook file as usual? Do I need to submit the HTML file of the\xa0embedded map as',
#   'modified': '2019-11-29T22:05:12Z',
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-29T21:42:19Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575057868884,
#   'rq': 0,
#   'id': 'k3kg167wevf151',
#   'unique_views': 100,
#   'score': 100.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 533,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-29T17:51:21Z', 'n': 'create'},
#    {'t': '2019-11-29T20:04:28Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'GroupBy Certain Criteria',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 3,
#   'content_snipet': 'For Project #4, suppose I wanted to create multiple maps displaying crime by sex/race and group by a certain criteria (i',
#   'modified': '2019-11-29T20:04:28Z',
#   'gd': 2,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'tag_good_prof': 1,
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-29T17:51:21Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575057650237,
#   'rq': 0,
#   'id': 'k3ji3jp95ym3b2',
#   'unique_views': 97,
#   'score': 97.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 532,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-29T02:01:24Z', 'n': 'create'},
#    {'t': '2019-11-29T20:00:29Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'},
#    {'t': '2019-11-29T20:00:50Z',
#     'u': 'iv9hhjrk2iv2w7',
#     'n': 'i_answer_update'}],
#   'subject': 'markers vs circles',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 5,
#   'content_snipet': 'in this description it says to add graphical elements. is there a different between a marker and a circle? is it okay if',
#   'modified': '2019-11-29T20:00:50Z',
#   'gd': 1,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-29T02:01:24Z',
#   'status': 'active'},
#  {'fol': 'final_tutorial|',
#   'm': 1575166709676,
#   'rq': 0,
#   'id': 'k3izxakoy68212',
#   'unique_views': 102,
#   'score': 102.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['final_tutorial'],
#   'nr': 531,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-28T17:32:40Z', 'u': 'j9ab71s5o5d2hm', 'n': 'create'},
#    {'t': '2019-12-01T02:18:29Z', 'n': 's_answer'}],
#   'subject': 'Final Tutorial Group',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I haven&#39;t started the final tutorial and was looking for a group to do it in. If anyone is in the same spot as me, m',
#   'modified': '2019-12-01T02:18:29Z',
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['final_tutorial', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-28T17:32:40Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575057829385,
#   'rq': 0,
#   'id': 'k3ibarcfk275if',
#   'unique_views': 110,
#   'score': 110.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 530,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-28T06:03:17Z', 'n': 'create'},
#    {'t': '2019-11-29T20:03:49Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'More Info about the data?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Is there a link to information about this data? Like what do all of the abbreviations of race stand for?\n\n',
#   'modified': '2019-11-29T20:03:49Z',
#   'gd': 5,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'tag_good_prof': 1,
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-28T06:03:17Z',
#   'status': 'active'},
#  {'fol': 'project|logistics|',
#   'm': 1575056991985,
#   'rq': 0,
#   'id': 'k3hko3drqb368',
#   'unique_views': 132,
#   'score': 132.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project', 'logistics'],
#   'nr': 529,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-27T17:37:50Z', 'n': 'create'},
#    {'t': '2019-11-27T23:52:15Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'},
#    {'t': '2019-11-29T19:35:09Z', 'n': 'followup'},
#    {'t': '2019-11-29T19:49:51Z', 'n': 'feedback'}],
#   'subject': 'Can we get an update on the state of the projects?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 14,
#   'content_snipet': 'It just feels like there&#39;s been some radio silence on piazza lately about projects and considering they are 65% of o',
#   'modified': '2019-11-29T19:49:51Z',
#   'gd': 10,
#   'has_i': True,
#   'num_favorites': 1,
#   'tags': ['logistics', 'project', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-27T17:37:50Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1574911108654,
#   'rq': 0,
#   'id': 'k3hklxg5hv81xw',
#   'unique_views': 128,
#   'score': 128.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 528,
#   'main_version': 5,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-27T17:36:09Z', 'n': 'create'},
#    {'t': '2019-11-27T17:39:37Z', 'n': 's_answer'},
#    {'t': '2019-11-27T18:22:57Z', 'n': 'followup'},
#    {'t': '2019-11-28T02:23:40Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'},
#    {'t': '2019-11-28T03:18:28Z',
#     'u': 'iv9hhjrk2iv2w7',
#     'n': 'i_answer_update'}],
#   'subject': 'Cannot view the readme for p4',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': 'So my readme file appears as an HTML or similar structure and I cannot view it.Any suggestions?',
#   'modified': '2019-11-28T03:18:28Z',
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-27T17:36:09Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1575296167566,
#   'rq': 0,
#   'id': 'k3hfzq57nd1p8',
#   'unique_views': 97,
#   'score': 97.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 527,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-27T15:26:55Z', 'n': 'create'},
#    {'t': '2019-11-27T15:33:31Z', 'n': 'update'},
#    {'t': '2019-12-02T14:16:07Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Project 4: Number of graphical elements required',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'How many graphical elements do we need to add the map? \n(Ex: would it be enough to just add circles indicating sex/race?',
#   'modified': '2019-12-02T14:16:07Z',
#   'gd': 9,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-27T15:26:55Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1574907862704,
#   'rq': 0,
#   'id': 'k3gh66cr89d5bc',
#   'unique_views': 124,
#   'score': 124.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 525,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T23:12:09Z', 'n': 'create'},
#    {'t': '2019-11-26T23:14:49Z', 'n': 's_answer'},
#    {'t': '2019-11-28T02:24:22Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'Project 4 Could not load data on map',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 5,
#   'content_snipet': 'I think the given dataset is too big that I could not mark location on the folium map, any suggestions for solving this ',
#   'modified': '2019-11-28T02:24:22Z',
#   'gd': 1,
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T23:12:09Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1575295938268,
#   'rq': 0,
#   'id': 'k3fmkpheyam4a7',
#   'unique_views': 122,
#   'score': 122.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 523,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T08:55:39Z', 'n': 'create'},
#    {'t': '2019-12-02T14:12:18Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Points distribution for project 3',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'What is the points distribution for project 3?\xa0 Since it is unlikely that project 3 will be officially graded before the',
#   'modified': '2019-12-02T14:12:18Z',
#   'gd': 7,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T08:55:39Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574740697466,
#   'rq': 0,
#   'id': 'k3fbyanutx7eo',
#   'unique_views': 110,
#   'score': 110.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 519,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T03:58:17Z', 'n': 'create'}],
#   'subject': 'Submitting csv file?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'For now the project submission on elms only accepts .ipynb files, could you open up to csv file as well so we can submit',
#   'modified': '2019-11-26T03:58:17Z',
#   'gd': 2,
#   'num_favorites': 0,
#   'tags': ['project3', 'student', 'unanswered'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 1,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-26T03:58:17Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574739530386,
#   'rq': 0,
#   'id': 'k3falpkjtc22e2',
#   'unique_views': 148,
#   'score': 148.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 518,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T03:20:30Z', 'n': 'create'},
#    {'t': '2019-11-26T03:37:05Z', 'u': 'if15rrwundl71u', 'n': 'followup'},
#    {'t': '2019-11-26T03:38:21Z', 'u': 'if15rrwundl71u', 'n': 'feedback'}],
#   'subject': 'How heavy is the Try it out part?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student', 'unanswered'],
#   'gd_f': 0,
#   'content_snipet': 'like 10% of the project 3?',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-11-26T03:38:50Z',
#   'gd': 11,
#   'updated': '2019-11-26T03:20:30Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574737872058,
#   'rq': 0,
#   'id': 'k3fa9qkat0yo',
#   'unique_views': 109,
#   'score': 109.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 517,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T03:11:12Z', 'n': 'create'}],
#   'subject': 'How can estimate errors?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student', 'unanswered'],
#   'gd_f': 0,
#   'content_snipet': 'I&#39;m so confused by the requirement of reporting error estimate. Is there any kind of function in sklearn we can use ',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-11-26T03:11:12Z',
#   'gd': 4,
#   'updated': '2019-11-26T03:11:12Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574737907216,
#   'rq': 0,
#   'id': 'k3f7c507zq82i',
#   'unique_views': 148,
#   'score': 148.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 516,
#   'main_version': 5,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T01:49:05Z', 'u': 'if15rrwundl71u', 'n': 'create'},
#    {'t': '2019-11-26T02:03:45Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-26T02:03:56Z',
#     'u': 'idx3g94pfq357h',
#     'n': 'i_answer_update'},
#    {'t': '2019-11-26T02:20:33Z', 'n': 'followup'},
#    {'t': '2019-11-26T03:11:47Z', 'n': 'feedback'}],
#   'subject': 'cross validation and paired ttests',
#   'no_answer_followup': 1,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I read &#64;458 but I don&#39;t think it quite answers this.\n\nI get that we are doing 10-fold CV, and we want scores for',
#   'modified': '2019-11-26T03:11:47Z',
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T01:49:05Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574739397670,
#   'rq': 0,
#   'id': 'k3f74rjeg5to',
#   'unique_views': 115,
#   'score': 115.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 515,
#   'main_version': 6,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T01:43:21Z', 'n': 'create'},
#    {'t': '2019-11-26T01:51:59Z', 'u': 'if15rrwundl71u', 'n': 's_answer'},
#    {'t': '2019-11-26T01:53:16Z', 'n': 'followup'},
#    {'t': '2019-11-26T01:57:51Z', 'u': 'if15rrwundl71u', 'n': 'feedback'},
#    {'t': '2019-11-26T03:28:35Z', 'n': 'feedback'},
#    {'t': '2019-11-26T03:36:37Z', 'u': 'if15rrwundl71u', 'n': 'feedback'}],
#   'subject': 'hyperparameters clarification',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'so, if i do 10 fold CV on some algorithm, and record accuracies, i would ideally choose the hyperparameters that give th',
#   'modified': '2019-11-26T03:36:37Z',
#   'gd': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T01:43:21Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574731940483,
#   'rq': 0,
#   'id': 'k3f6k7tk7kl2oi',
#   'unique_views': 134,
#   'score': 134.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 514,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T01:27:22Z', 'n': 'create'},
#    {'t': '2019-11-26T01:32:20Z', 'n': 's_answer'}],
#   'subject': 'Resubmitting',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Are we allowed to resubmit the project multiple times? In order to correct a mistake we made earlier for example.',
#   'modified': '2019-11-26T01:32:20Z',
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-26T01:27:22Z',
#   'status': 'active'},
#  {'fol': 'project2|',
#   'm': 1574727691542,
#   'rq': 0,
#   'id': 'k3f47j86kg22g7',
#   'unique_views': 155,
#   'score': 155.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project2'],
#   'nr': 513,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T00:21:31Z', 'n': 'create'}],
#   'subject': 'Project 2 Grades?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project2', 'student', 'unanswered'],
#   'gd_f': 0,
#   'content_snipet': 'Bumping &#64;472. Thanks =)',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-11-26T00:21:31Z',
#   'gd': 3,
#   'updated': '2019-11-26T00:21:31Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574732289542,
#   'rq': 0,
#   'id': 'k3f43v8uzep15s',
#   'unique_views': 135,
#   'score': 135.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'has_i': True,
#   'folders': ['project3'],
#   'nr': 512,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T00:18:40Z', 'n': 'create'},
#    {'t': '2019-11-26T00:25:13Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-26T00:34:58Z', 'n': 'followup'},
#    {'t': '2019-11-26T01:38:09Z', 'n': 'update'}],
#   'subject': 'deleted',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'content_snipet': 'deleted',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-11-26T01:38:09Z',
#   'updated': '2019-11-26T00:18:40Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574735205278,
#   'rq': 0,
#   'id': 'k3f422l77cf4p5',
#   'unique_views': 134,
#   'score': 134.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'has_i': True,
#   'folders': ['project3'],
#   'nr': 511,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-26T00:17:16Z', 'n': 'create'},
#    {'t': '2019-11-26T00:25:55Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-26T02:26:45Z', 'u': 'jjikbccza9671h', 'n': 'followup'}],
#   'subject': 'Try it out classification or regression',
#   'no_answer_followup': 1,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'content_snipet': 'The Readme says that you could either do classification or regression. However, I&#39;ve seen on piazza that you need cl',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-11-26T02:26:45Z',
#   'updated': '2019-11-26T00:17:16Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574726712138,
#   'rq': 0,
#   'id': 'k3f2riupgbv4oj',
#   'unique_views': 134,
#   'score': 134.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 510,
#   'main_version': 5,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T23:41:04Z', 'n': 'create'},
#    {'t': '2019-11-25T23:51:39Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-25T23:57:23Z', 'n': 'followup'},
#    {'t': '2019-11-25T23:58:55Z', 'u': 'idx3g94pfq357h', 'n': 'feedback'},
#    {'t': '2019-11-26T00:05:12Z', 'n': 'feedback'}],
#   'subject': 'graph for part 3',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Can someone let me know which graph is correct? Is the graph for the logistic regression for gradient descent supposed t',
#   'modified': '2019-11-26T00:05:12Z',
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-25T23:41:04Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574724536188,
#   'rq': 0,
#   'id': 'k3f26uujksx5hk',
#   'unique_views': 132,
#   'score': 132.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 509,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T23:25:00Z', 'n': 'create'},
#    {'t': '2019-11-25T23:28:56Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'}],
#   'subject': 'Part 2 Problem 3',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Hi, I&#39;m very confused as to how to apply the formulas under problem 1 to problem 3 in order to implement the gradien',
#   'modified': '2019-11-25T23:28:56Z',
#   'gd': 2,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 1,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T23:25:00Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574725651303,
#   'rq': 0,
#   'id': 'k3f1di1nmxl6ig',
#   'unique_views': 130,
#   'score': 130.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'has_i': True,
#   'folders': ['project3'],
#   'nr': 507,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T23:02:11Z', 'n': 'create'},
#    {'t': '2019-11-25T23:47:31Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Do we have to write the cross-validation function ourselves?',
#   'no_answer_followup': 0,
#   'num_favorites': 1,
#   'type': 'question',
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'content_snipet': 'Or can we just make our own class for our logistic regression code, give it a fit and predict function, and use a pre-bu',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-11-25T23:47:31Z',
#   'updated': '2019-11-25T23:02:11Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1574818803746,
#   'rq': 0,
#   'id': 'k3ewhwvuhi25r0',
#   'unique_views': 153,
#   'score': 153.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['other'],
#   'nr': 505,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T20:45:38Z', 'u': 'hcjqqmhat2i461', 'n': 'create'},
#    {'t': '2019-11-25T22:41:17Z', 'n': 'followup'},
#    {'t': '2019-11-27T01:40:03Z', 'u': 'hcjqqmhat2i461', 'n': 'feedback'}],
#   'subject': 'Cancelling my 10am-12pm office hours on Wednesday, Nov 27',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'other'],
#   'gd_f': 0,
#   'content_snipet': 'I&#39;m cancelling my office hours on Wednesday morning since I assume no one will show up on a day right after a projec',
#   'view_adjust': 0,
#   'modified': '2019-11-27T01:40:03Z',
#   'updated': '2019-11-25T20:45:38Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574820327452,
#   'rq': 0,
#   'id': 'k3ew8r21pgr3p6',
#   'unique_views': 204,
#   'score': 204.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 504,
#   'main_version': 62,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T20:38:31Z', 'n': 'create'},
#    {'t': '2019-11-25T21:02:05Z', 'n': 'update'},
#    {'t': '2019-11-25T21:15:59Z', 'n': 's_answer'},
#    {'t': '2019-11-25T21:16:20Z', 'n': 'followup'},
#    {'t': '2019-11-25T21:53:39Z', 'n': 'followup'},
#    {'t': '2019-11-25T21:56:06Z', 'n': 'feedback'},
#    {'t': '2019-11-25T21:56:50Z', 'n': 'feedback'},
#    {'t': '2019-11-25T22:05:01Z', 'n': 'followup'},
#    {'t': '2019-11-25T22:10:09Z', 'u': 'jlgkhem7a006ij', 'n': 'followup'},
#    {'t': '2019-11-25T22:12:38Z', 'n': 'feedback'},
#    {'t': '2019-11-25T22:12:40Z', 'n': 'feedback'},
#    {'t': '2019-11-25T22:55:02Z', 'n': 'feedback'},
#    {'t': '2019-11-25T23:41:04Z', 'n': 'feedback'},
#    {'t': '2019-11-25T23:41:30Z', 'n': 'feedback'},
#    {'t': '2019-11-25T23:41:42Z', 'n': 'followup'},
#    {'t': '2019-11-25T23:46:34Z', 'u': 'jsm892641aymp', 'n': 'feedback'},
#    {'t': '2019-11-26T00:14:26Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:14:40Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:14:47Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:15:41Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:16:13Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:16:30Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:17:09Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:17:44Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:22:00Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:23:12Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:28:34Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:35:06Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:41:51Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:45:03Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:47:56Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:47:59Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:02Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:06Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:20Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:31Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:48:39Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:50:32Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:54:24Z', 'n': 'feedback'},
#    {'t': '2019-11-26T00:58:22Z', 'n': 'followup'},
#    {'t': '2019-11-26T00:59:00Z', 'n': 'feedback'},
#    {'t': '2019-11-26T01:02:20Z', 'n': 'feedback'},
#    {'t': '2019-11-26T01:02:55Z', 'n': 'feedback'},
#    {'t': '2019-11-26T01:16:54Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:18:43Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:19:31Z', 'n': 'feedback'},
#    {'t': '2019-11-26T01:19:41Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:23:01Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:23:38Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:24:58Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:26:32Z', 'u': 'jrh3tnn73fw8r', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:28:01Z', 'u': 'jrh3tnn73fw8r', 'n': 's_answer_update'},
#    {'t': '2019-11-26T01:31:56Z', 'u': 'jrz96gwn7f66ak', 'n': 'followup'},
#    {'t': '2019-11-26T01:58:43Z', 'n': 's_answer_update'},
#    {'t': '2019-11-26T02:18:02Z', 'n': 'feedback'},
#    {'t': '2019-11-26T02:32:21Z', 'n': 'followup'},
#    {'t': '2019-11-26T02:35:38Z', 'n': 'feedback'},
#    {'t': '2019-11-26T03:07:58Z', 'n': 'feedback'},
#    {'t': '2019-11-26T03:13:00Z', 'n': 'feedback'},
#    {'t': '2019-11-26T05:26:25Z', 'n': 'followup'},
#    {'t': '2019-11-26T05:35:43Z', 'n': 'followup'},
#    {'t': '2019-11-27T02:05:27Z', 'n': 'followup'}],
#   'subject': 'One Last Extension Please?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 32,
#   'content_snipet': 'There are so many people in office hours, and it is much more difficult than other projects, so could you please give on',
#   'modified': '2019-11-27T02:05:27Z',
#   'gd': 73,
#   'has_s': True,
#   'num_favorites': 3,
#   'tags': ['project3', 'student'],
#   'tag_good_prof': 1,
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T20:38:31Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574721917718,
#   'rq': 0,
#   'id': 'k3ev2dnfpht1kn',
#   'unique_views': 151,
#   'score': 151.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 502,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T20:05:34Z', 'n': 'create'},
#    {'t': '2019-11-25T22:45:17Z', 'n': 's_answer'}],
#   'subject': 'Project 3 Rubric',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Will we be given a rubric for Project 3?',
#   'modified': '2019-11-25T22:45:17Z',
#   'gd': 9,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T20:05:34Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574718009244,
#   'rq': 0,
#   'id': 'k3eutmq2qy95yq',
#   'unique_views': 169,
#   'score': 169.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 501,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T19:58:46Z', 'n': 'create'},
#    {'t': '2019-11-25T21:39:13Z', 'u': 'jle6g1r73v07pa', 'n': 's_answer'},
#    {'t': '2019-11-25T21:40:09Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Dataset for &#34;Try it out&#34;',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 2,
#   'content_snipet': 'Can we use the dataset used in part 1 for the &#34;Try it out&#34; Section?\xa0\n\nThank you!\xa0',
#   'modified': '2019-11-25T21:40:09Z',
#   'gd': 1,
#   'has_i': True,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T19:58:46Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574717941494,
#   'rq': 0,
#   'id': 'k3etz0a6i4y5rv',
#   'unique_views': 134,
#   'score': 134.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'has_i': True,
#   'folders': ['project3'],
#   'nr': 500,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T19:34:57Z', 'n': 'create'},
#    {'t': '2019-11-25T21:39:01Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Can I use GridSearchCV to find best parameters?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'content_snipet': '',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-11-25T21:39:01Z',
#   'updated': '2019-11-25T19:34:57Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574721564071,
#   'rq': 0,
#   'id': 'k3esa5m5m4i6xc',
#   'unique_views': 132,
#   'score': 132.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 499,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T18:47:38Z', 'n': 'create'},
#    {'t': '2019-11-25T21:43:36Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'},
#    {'t': '2019-11-25T22:39:24Z', 'n': 's_answer'}],
#   'subject': 'Siting sources for the derivation of part 2',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 3,
#   'content_snipet': 'Are we allowed to use other sources to figure out the derivation of the update equation?',
#   'modified': '2019-11-25T22:39:24Z',
#   'has_i': True,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-25T18:47:38Z',
#   'status': 'active'},
#  {'fol': 'project4|',
#   'm': 1574707858057,
#   'rq': 0,
#   'id': 'k3ersb3o85p34s',
#   'unique_views': 180,
#   'score': 180.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project4'],
#   'nr': 498,
#   'main_version': 7,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T18:33:45Z', 'n': 'create'},
#    {'t': '2019-11-25T18:34:46Z', 'n': 's_answer'},
#    {'t': '2019-11-25T18:38:02Z', 'n': 'followup'},
#    {'t': '2019-11-25T18:38:36Z', 'n': 's_answer_update'},
#    {'t': '2019-11-25T18:39:52Z', 'u': 'j6wriis2x1oic', 'n': 's_answer_update'},
#    {'t': '2019-11-25T18:46:38Z', 'n': 'feedback'},
#    {'t': '2019-11-25T18:50:58Z', 'n': 'feedback'}],
#   'subject': 'TA not here',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Saeed not here for his office hours. Considering the project is due today, this is unacceptable. At least someone should',
#   'modified': '2019-11-25T18:50:58Z',
#   'gd': 3,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project4', 'student'],
#   'gd_f': 1,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-25T18:33:45Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574707705445,
#   'rq': 0,
#   'id': 'k3erhrju7u919l',
#   'unique_views': 150,
#   'score': 150.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 497,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T18:25:33Z', 'n': 'create'},
#    {'t': '2019-11-25T18:26:28Z', 'u': 'j6wriis2x1oic', 'n': 's_answer'},
#    {'t': '2019-11-25T18:26:52Z', 'n': 'followup'},
#    {'t': '2019-11-25T18:48:25Z', 'u': 'idx3g94pfq357h', 'n': 'feedback'}],
#   'subject': 'What is the loss function for logistic gradient descent?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Question in title; thanks!',
#   'modified': '2019-11-25T18:48:25Z',
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T18:25:33Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574704287516,
#   'rq': 0,
#   'id': 'k3ep59apq3w4fm',
#   'unique_views': 129,
#   'score': 129.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 496,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T17:19:51Z', 'n': 'create'},
#    {'t': '2019-11-25T17:51:27Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'External Source Use',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'If we use outside sources to help write our code for the multiple logistic regression, should we cite them in a comment ',
#   'modified': '2019-11-25T17:51:27Z',
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-11-25T17:19:51Z',
#   'status': 'active'},
#  {'fol': 'exam|',
#   'm': 1574800284217,
#   'rq': 0,
#   'id': 'k3emy8747mv3qw',
#   'unique_views': 133,
#   'score': 133.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['exam'],
#   'nr': 495,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T16:18:23Z', 'n': 'create'},
#    {'t': '2019-11-25T19:27:35Z', 'u': 'jrgrxaenjy9t5', 'n': 'i_answer'},
#    {'t': '2019-11-26T20:28:43Z', 'n': 's_answer'},
#    {'t': '2019-11-26T20:31:24Z', 'n': 'followup'}],
#   'subject': 'Exam: Multiple Choice Confusion',
#   'no_answer_followup': 1,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': '\nFor question 2b (the correct answer was iii) I circled 2 answers. Since I circled the right answer and 1 wrong answer, ',
#   'modified': '2019-11-26T20:31:24Z',
#   'gd': 2,
#   'has_i': True,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['exam', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-11-25T16:18:23Z',
#   'status': 'active'},
#  {'fol': 'project3|',
#   'm': 1574701311117,
#   'rq': 0,
#   'id': 'k3e8ttypn5c5lj',
#   'unique_views': 148,
#   'score': 148.0,
#   'is_new': True,
#   'bucket_name': 'Last week',
#   'bucket_order': 5,
#   'folders': ['project3'],
#   'nr': 494,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-11-25T09:43:04Z', 'n': 'create'},
#    {'t': '2019-11-25T17:01:51Z', 'u': 'idx3g94pfq357h', 'n': 'i_answer'}],
#   'subject': 'Dataset',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'content_snipet': 'Since we&#39;re using our logistic regression, should our dataset for the try it out section only have 2 categories?',
#   'modified': '2019-11-25T17:01:51Z',
#   'gd': 1,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['project3', 'student'],
#   'gd_f': 0,
#   'view_adjust': 0,
#   'no_answer': 0,
# ...
#    {'t': '2019-08-29T21:46:10Z', 'n': 'followup'},
#    {'t': '2019-08-29T22:34:16Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-08-29T22:35:26Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'feedback'},
#    {'t': '2019-09-10T04:44:04Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'update'}],
#   'subject': 'Quiz #1 is Live!',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'other'],
#   'content_snipet': 'Quiz 1 is now live on ELMS.\xa0 I&#39;ve also just pushed the supporting Jupyter Notebook to the public Github repository (',
#   'view_adjust': 0,
#   'modified': '2019-09-10T04:44:04Z',
#   'updated': '2019-08-29T20:15:31Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1567092792894,
#   'rq': 0,
#   'id': 'jzw6odpkrrb25h',
#   'unique_views': 168,
#   'score': 168.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 19,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T04:23:52Z', 'n': 'create'},
#    {'t': '2019-08-29T15:33:12Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'TA office hours',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'When will TA office hours be posted? I&#39;m having trouble with docker and was planning to go to office hours.',
#   'modified': '2019-08-29T15:33:12Z',
#   'gd': 2,
#   'has_i': True,
#   'num_favorites': 0,
#   'tags': ['other', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-29T04:23:52Z',
#   'status': 'active'},
#  {'fol': 'project|',
#   'm': 1567112675272,
#   'rq': 0,
#   'id': 'jzw673pqlxt59g',
#   'unique_views': 206,
#   'score': 206.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['project'],
#   'nr': 18,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T04:10:26Z', 'n': 'create'},
#    {'t': '2019-08-29T14:21:49Z', 'n': 's_answer'},
#    {'t': '2019-08-29T21:04:35Z', 'n': 'followup'}],
#   'subject': 'Jupyter Notebook',
#   'no_answer_followup': 1,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Got to the part\xa0 in the doc where I&#39;m entering the command:\n\ndocker run -it -v PWD/project0/home/jovyan/notebooks --',
#   'modified': '2019-08-29T21:04:35Z',
#   'gd': 2,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-29T04:10:26Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1572983645544,
#   'rq': 0,
#   'id': 'jzw5179dohl3ca',
#   'unique_views': 269,
#   'score': 269.0,
#   'is_new': False,
#   'version': 1,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 17,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T03:37:51Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'create'},
#    {'t': '2019-11-05T19:54:05Z', 'u': 'jrgrxaenjy9t5', 'n': 'update'}],
#   'subject': 'Piazza Best Practices',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['instructor-note', 'other'],
#   'content_snipet': 'If folks post a question on Piazza, and that question is answered,\xa0please\xa0update your post with how you solved that prob',
#   'view_adjust': 0,
#   'modified': '2019-11-05T19:54:05Z',
#   'gd': 3,
#   'updated': '2019-08-29T03:37:51Z',
#   'status': 'active'},
#  {'fol': 'logistics|',
#   'm': 1567047168106,
#   'rq': 0,
#   'id': 'jzw3539mqmu3ek',
#   'unique_views': 198,
#   'score': 198.0,
#   'is_new': False,
#   'version': 3,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['logistics'],
#   'nr': 16,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T02:44:53Z', 'n': 'create'},
#    {'t': '2019-08-29T02:50:54Z', 'n': 'update'},
#    {'t': '2019-08-29T02:52:48Z', 'n': 'update'}],
#   'subject': 'Is Docker a Requirement?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['logistics', 'student', 'unanswered'],
#   'content_snipet': 'I have a really slow and old Windows computer and I cannot figure out how to make Docker work. Can I just get a list of ',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-08-29T02:52:48Z',
#   'gd': 3,
#   'updated': '2019-08-29T02:44:53Z',
#   'status': 'active'},
#  {'fol': 'project|',
#   'm': 1567112320748,
#   'rq': 0,
#   'id': 'jzw0pgt4r8f545',
#   'unique_views': 205,
#   'score': 205.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['project'],
#   'nr': 15,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-29T01:36:45Z', 'n': 'create'},
#    {'t': '2019-08-29T02:58:51Z', 'u': 'j79r0cp61395ue', 'n': 's_answer'},
#    {'t': '2019-08-29T04:40:12Z', 'n': 'followup'},
#    {'t': '2019-08-29T20:58:40Z', 'u': 'jlgkhlh2usf6og', 'n': 'feedback'}],
#   'subject': 'Jupyter Setup with Docker',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I set up Docker correctly but when I try to run the command to set up the notebooks after everything has downloaded, I g',
#   'modified': '2019-08-29T20:58:40Z',
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['project', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-08-29T01:36:45Z',
#   'status': 'active'},
#  {'fol': 'logistics|',
#   'm': 1570339657301,
#   'rq': 0,
#   'id': 'jzvqsybkhix2nw',
#   'unique_views': 184,
#   'score': 184.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['logistics'],
#   'nr': 14,
#   'main_version': 12,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T20:59:31Z', 'u': 'jzubd7n5asc3kp', 'n': 'create'},
#    {'t': '2019-08-29T01:29:46Z', 'n': 's_answer'},
#    {'t': '2019-08-29T02:22:18Z', 'u': 'jzu83lw5k6o20g', 'n': 'followup'},
#    {'t': '2019-08-29T03:52:05Z', 'u': 'j6wriis2x1oic', 'n': 'feedback'},
#    {'t': '2019-08-29T13:50:03Z', 'u': 'jzubd7n5asc3kp', 'n': 'feedback'},
#    {'t': '2019-08-29T20:35:19Z', 'n': 'followup'},
#    {'t': '2019-08-29T21:42:10Z', 'u': 'jzubd7n5asc3kp', 'n': 'feedback'},
#    {'t': '2019-08-30T01:20:25Z', 'u': 'j6xuc2iutt72ad', 'n': 'feedback'},
#    {'t': '2019-08-30T03:45:12Z', 'u': 'j6xuc2iutt72ad', 'n': 'feedback'},
#    {'t': '2019-08-30T04:37:05Z', 'n': 'feedback'},
#    {'t': '2019-08-30T18:45:56Z', 'n': 'feedback'},
#    {'t': '2019-10-06T05:27:37Z', 'n': 'followup'}],
#   'subject': 'No notebooks in notebooks folder',
#   'no_answer_followup': 3,
#   'has_s': True,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['logistics', 'student'],
#   'content_snipet': 'When I open\xa0the notebooks folder, there aren&#39;t any notebooks there.\xa0Did I make an error during some part of the setu',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-10-06T05:27:37Z',
#   'gd': 9,
#   'updated': '2019-08-28T20:59:31Z',
#   'status': 'active'},
#  {'fol': 'logistics|',
#   'm': 1567443898415,
#   'rq': 0,
#   'id': 'jzvqm9h0h3s45f',
#   'unique_views': 171,
#   'score': 171.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['logistics'],
#   'nr': 13,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T20:54:19Z', 'n': 'create'},
#    {'t': '2019-09-02T02:18:51Z', 'n': 'followup'},
#    {'t': '2019-09-02T17:04:41Z', 'n': 'feedback'},
#    {'t': '2019-09-02T17:04:58Z', 'n': 's_answer'}],
#   'subject': 'Launched Jupyter but can only see a &#39;Work&#39; folder',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'Can&#39;t seem to find the notebooks directory as I have a single folder named Work.\n\nWhen I copied the command to termi',
#   'modified': '2019-09-02T17:04:58Z',
#   'gd': 9,
#   'has_s': True,
#   'num_favorites': 1,
#   'tags': ['logistics', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-28T20:54:19Z',
#   'status': 'active'},
#  {'fol': 'logistics|',
#   'm': 1567026093496,
#   'rq': 0,
#   'id': 'jzvlujir5h62v7',
#   'unique_views': 184,
#   'score': 184.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['logistics'],
#   'nr': 12,
#   'main_version': 9,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T18:40:47Z', 'n': 'create'},
#    {'t': '2019-08-28T18:44:22Z', 'n': 's_answer'},
#    {'t': '2019-08-28T18:46:58Z', 'n': 'followup'},
#    {'t': '2019-08-28T18:58:01Z', 'n': 'feedback'},
#    {'t': '2019-08-28T19:06:57Z', 'n': 'feedback'},
#    {'t': '2019-08-28T19:47:24Z', 'n': 'feedback'},
#    {'t': '2019-08-28T19:49:50Z', 'n': 'feedback'},
#    {'t': '2019-08-28T20:00:04Z', 'n': 'feedback'},
#    {'t': '2019-08-28T21:01:33Z', 'n': 'feedback'}],
#   'subject': 'Difficulty Setting Up Notebook',
#   'no_answer_followup': 0,
#   'has_s': True,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['logistics', 'student'],
#   'content_snipet': 'I believe I&#39;ve cloned the class repo and gotten Docker installed and running, but when I go to start a Jupyter Noteb',
#   'view_adjust': 0,
#   'no_answer': 0,
#   'modified': '2019-08-28T21:01:33Z',
#   'updated': '2019-08-28T18:40:47Z',
#   'status': 'active'},
#  {'fol': 'project|',
#   'm': 1567108097023,
#   'rq': 0,
#   'id': 'jzvjzojohex4b9',
#   'unique_views': 201,
#   'score': 201.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['project'],
#   'nr': 11,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T17:48:48Z', 'n': 'create'},
#    {'t': '2019-08-29T19:48:17Z', 'u': 'j8neqb407vv1uz', 'n': 's_answer'}],
#   'subject': 'Connecting to the Jupyter Notebook',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 4,
#   'content_snipet': 'I used the Docker Toolbox thing to set up Docker as described by the students&#39; answer in &#64;7. Everything seemed t',
#   'modified': '2019-08-29T19:48:17Z',
#   'gd': 7,
#   'has_s': True,
#   'num_favorites': 1,
#   'tags': ['project', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-28T17:48:48Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1567517562427,
#   'rq': 0,
#   'id': 'jzvhw9dkj507f0',
#   'unique_views': 184,
#   'score': 184.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 10,
#   'main_version': 6,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T16:50:09Z', 'u': 'jrhgoaszdc45x1', 'n': 'create'},
#    {'t': '2019-08-28T17:16:27Z', 'u': 'jrhgoaszdc45x1', 'n': 'update'},
#    {'t': '2019-08-29T03:39:23Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'followup'},
#    {'t': '2019-08-29T03:44:00Z', 'u': 'j6wriis2x1oic', 'n': 'feedback'},
#    {'t': '2019-09-03T13:03:48Z', 'u': 'jrhgoaszdc45x1', 'n': 'feedback'},
#    {'t': '2019-09-03T13:32:42Z', 'u': 'j6wriis2x1oic', 'n': 'feedback'}],
#   'subject': 'Is anyone else&#39;s project 0 code filled with syntax errors?',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'question',
#   'tags': ['other', 'student', 'unanswered'],
#   'content_snipet': 'I&#39;m fiddling around with the notebook as per the instructions and I keep getting errors on the basic syntax of the c',
#   'view_adjust': 0,
#   'no_answer': 1,
#   'modified': '2019-09-03T13:32:42Z',
#   'gd': 1,
#   'updated': '2019-08-28T16:50:09Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1567006170531,
#   'rq': 0,
#   'id': 'jzveukremfk37h',
#   'unique_views': 203,
#   'score': 203.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 9,
#   'main_version': 3,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T15:24:52Z', 'n': 'create'},
#    {'t': '2019-08-28T15:28:49Z', 'n': 's_answer'},
#    {'t': '2019-08-28T15:29:30Z', 'n': 's_answer_update'}],
#   'subject': 'Jupyter Notebook',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'The instructions say to replace PWD with the path to the git directory for the command line:\ndocker run -it -v PWD/proje',
#   'modified': '2019-08-28T15:29:30Z',
#   'gd': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['other', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-08-28T15:24:52Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1566966877405,
#   'rq': 0,
#   'id': 'jzurl4q7nmc4ge',
#   'unique_views': 176,
#   'score': 176.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 8,
#   'main_version': 2,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T04:33:40Z', 'u': 'jlgkhqea1gz6s1', 'n': 'create'},
#    {'t': '2019-08-28T04:34:37Z', 'u': 'jlgkhqea1gz6s1', 'n': 'update'}],
#   'subject': 'ProPublica&#39;s Analysis of the COMPAS Algorithm',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['other', 'student', 'unanswered'],
#   'tag_good_prof': 1,
#   'content_snipet': 'Hey y&#39;all! \xa0\n\nDuring today&#39;s lecture, I mentioned a ProPublica study about how COMPAS, a tool used by judges, pr',
#   'view_adjust': 0,
#   'modified': '2019-08-28T04:34:37Z',
#   'd-bucket': 'Yesterday',
#   'gd': 3,
#   'updated': '2019-08-28T04:33:40Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1567011397874,
#   'rq': 0,
#   'id': 'jzuit4bewc9a1',
#   'unique_views': 221,
#   'score': 221.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 7,
#   'main_version': 7,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-28T00:27:56Z', 'n': 'create'},
#    {'t': '2019-08-28T01:14:53Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'},
#    {'t': '2019-08-28T01:44:34Z', 'n': 's_answer'},
#    {'t': '2019-08-28T01:45:58Z',
#     'u': 'jlgkhrb24v66sm',
#     'n': 's_answer_update'},
#    {'t': '2019-08-28T01:46:04Z', 'n': 's_answer_update'},
#    {'t': '2019-08-28T14:44:40Z',
#     'u': 'iv9hhjrk2iv2w7',
#     'n': 'i_answer_update'},
#    {'t': '2019-08-28T16:56:37Z', 'n': 'followup'}],
#   'subject': 'Pro or Enterprise Version required?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 1,
#   'content_snipet': 'I am attempting to download Docker for Windows 10 from this link (https://hub.docker.com/?overlay=onboarding), however i',
#   'modified': '2019-08-28T16:56:37Z',
#   'gd': 3,
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 1,
#   'tags': ['other', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'd-bucket': 'Yesterday',
#   'updated': '2019-08-28T00:27:56Z',
#   'status': 'active'},
#  {'fol': 'other|',
#   'm': 1566937674374,
#   'rq': 0,
#   'id': 'jzu72r4ggz81or',
#   'unique_views': 221,
#   'score': 221.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/25 - 8/31',
#   'bucket_order': 19,
#   'folders': ['other'],
#   'nr': 6,
#   'main_version': 4,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-27T18:59:30Z', 'n': 'create'},
#    {'t': '2019-08-27T18:59:54Z', 'n': 'update'},
#    {'t': '2019-08-27T19:55:09Z', 'u': 'if15rrwundl71u', 'n': 's_answer'},
#    {'t': '2019-08-27T20:27:54Z', 'u': 'iv9hhjrk2iv2w7', 'n': 'i_answer'}],
#   'subject': 'Elms?',
#   'no_answer_followup': 0,
#   'type': 'question',
#   'gd_a': 6,
#   'content_snipet': 'Is the elms ready yet?I did not see 320 in my elms.',
#   'modified': '2019-08-27T20:27:54Z',
#   'has_i': True,
#   'tag_endorse_prof': 1,
#   'has_s': True,
#   'num_favorites': 0,
#   'tags': ['other', 'student'],
#   'view_adjust': 0,
#   'no_answer': 0,
#   'updated': '2019-08-27T18:59:30Z',
#   'status': 'active'},
#  {'fol': '',
#   'm': 1566428620181,
#   'rq': 0,
#   'id': 'jzlv5ms5w434u1',
#   'unique_views': 157,
#   'score': 157.0,
#   'is_new': True,
#   'bucket_name': 'Week 8/18 - 8/24',
#   'bucket_order': 20,
#   'folders': [],
#   'nr': 1,
#   'main_version': 1,
#   'request_instructor': 0,
#   'log': [{'t': '2019-08-21T23:03:40Z', 'u': 'gd6v7134AUa', 'n': 'create'}],
#   'subject': 'Welcome to Piazza!',
#   'no_answer_followup': 0,
#   'num_favorites': 0,
#   'type': 'note',
#   'tags': ['student'],
#   'content_snipet': "\nPiazza is a Q&A platform designed to get you great answers from classmates and instructors fast. We've put together thi",
#   'view_adjust': 0,
#   'modified': '2019-08-21T23:03:40Z',
#   'updated': '2019-08-21T23:03:40Z',
#   'status': 'active'}]

# %%
import pandas as pd

# %%
posts = pd.DataFrame(columns = ['posted', 'total_replies', 'instructor_replies', 'unique_views', 'num_favs'] 
                     + folders + ['subject'])

# THIS CELL NOT DONE YET. RANDOM DATA IS ADDED INTO THE FRAME AS A TEST
# Need to actually set each piece of data based on the dict
from numpy.random import randint
for i in range(len(posts_dict)):
    posts.loc[i] = list(randint(10, size=28))
posts.head()
# Out:
#   posted total_replies instructor_replies unique_views num_favs quiz1 quiz2  \
# 0      0             2                  1            2        3     6     2
# 1      4             2                  6            7        8     7     9
# 2      8             4                  4            5        5     0     5
# 3      6             7                  2            1        8     4     3
# 4      7             9                  7            1        5     9     9
#
#   quiz3 quiz4 quiz5  ... project2 project3 project4 midterm_exam  \
# 0     7     6     5  ...        0        3        5            0
# 1     7     0     8  ...        4        9        0            8
# 2     0     1     0  ...        0        8        7            9
# 3     9     2     5  ...        2        9        7            9
# 4     5     7     5  ...        0        5        2            8
#
#   final_tutorial other project exam logistics subject
# 0              1     2       7    9         6       9
# 1              7     7       7    1         8       3
# 2              5     9       6    8         1       9
# 3              5     1       5    0         7       3
# 4              3     6       4    8         9       4
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %% [markdown]
# ## Analysis, Hypothesis Testing and ML

# %% [markdown]
# ## Insight and Policy Decision

# %%
#Erika was here
